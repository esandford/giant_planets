# %%
import numpy as np
import matplotlib.pyplot as plt

import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')

import baraffe_tables
from baraffe_tables.table_search import baraffe_table_search

from astropy.table import Table
from astropy import units as u
from astropy.constants import G

import mesa_helper as mh
import os
import shutil

# %matplotlib inline

# %%
mJtomSun = u.jupiterMass.to(u.solMass)
mJtoGrams = u.jupiterMass.to(u.g)

rJtorSun = u.jupiterRad.to(u.solRad)
rJtoCm = u.jupiterRad.to(u.cm)

print(mJtomSun)
print(mJtoGrams)
print(rJtorSun)
print(rJtoCm)
# Out:
# 0.0009545942339693249
# 1.8981245973360504e+30
# 0.10276268506540176
# 7149200000.0

# %%
print(5*rJtoCm)
# Out:
# 35746000000.0

# %%
#jupiter masses
#Minit = np.array((20.0, 14.0, 9.8, 6.9, 4.8, 3.4, 2.3, 1.6, 1.1, 0.82, 0.57, 0.4, 0.28, 0.2))
Minit = np.atleast_1d(np.array((0.2)))

#jupiter radii
Rinit = np.array((5.0, 2.0, 1.5, 1.0, 0.75, 0.5))
#Rinit = np.array((2.0, 1.75, 1.5, 1.25, 1.0, 0.75, 0.5, 0.25, 0.1))
#Rinit = np.array((0.75, 0.5))

# %%
# make directories for all planet initial masses
os.chdir('/Users/Emily/Documents/astro/giant_planets/MESAtests/reproducePaxton+2011fig18')
    
for i, m in enumerate(Minit):
    os.system("rm -r Minit={0}Mj".format(m))
    os.system("cp -r template_makeplanet Minit={0}Mj".format(m))

#edit inlist_create, inlist_evolve, rn
for i, m in enumerate(Minit):
    print(m)
    #edit inlists
    create_model_filename = "planet_create_{0}_Mj_{1}_Rj.mod".format(m, Rinit[0])
    evolve_model_filename = "planet_evolve_{0}_Mj_{1}_Rj.mod".format(m, Rinit[0])

    inlist_create = mh.Inlist('./Minit={0}Mj/inlist_create'.format(m))
    inlist_evolve = mh.Inlist('./Minit={0}Mj/inlist_evolve'.format(m))

    #edit inlist_create options
    inlist_create.set_option('mass_in_gm_for_create_initial_model', m*mJtoGrams)
    # start with initial radius equal to 5 Rj. This will need to be revised downward for less massive planets.
    # If it needs to be revised to be very small, may also need to change kap_lowT_prefix option.
    inlist_create.set_option('radius_in_cm_for_create_initial_model', Rinit[0]*rJtoCm)
    inlist_create.set_option('save_model_filename', create_model_filename)
    inlist_create.set_option('initial_model_relax_num_steps', 50)

    #edit inlist_evolve options
    inlist_evolve.set_option('load_model_filename', create_model_filename)
    inlist_evolve.set_option('save_model_filename', evolve_model_filename)
    inlist_evolve.set_option('mesh_delta_coeff', 1.0)
    if m < 0.3:
        inlist_create.set_option('irradiation_flux', 5.e4)
        inlist_create.set_option('column_depth_for_irradiation', 500.0)
        inlist_evolve.set_option('irradiation_flux', 5.e4)
        inlist_evolve.set_option('column_depth_for_irradiation', 500.0)
    
    
    # edit rn script
    f = open('./Minit={0}Mj/rn'.format(m), 'r')
    g = f.read()
    f.close()
    #print(g)
    g = g.replace("<<create_model_filename>>", create_model_filename)
    g = g.replace("<<evolve_model_filename>>", evolve_model_filename)
    
    h = open('./Minit={0}Mj/rn_temp'.format(m), 'w')
    h.write(g)
    h.close()
    shutil.copyfile('./Minit={0}Mj/rn_temp'.format(m),'./Minit={0}Mj/rn'.format(m))
    
    # execute mk script
    os.chdir('./Minit={0}Mj/'.format(m))
    os.system('./mk'.format(m))
    os.chdir('..')
# Out:
# 0.2
# Set mass_in_gm_for_create_initial_model to 3.79625d29
# Set radius_in_cm_for_create_initial_model to 3.5746d10
# Set save_model_filename to 'planet_create_0.2_Mj_5.0_Rj.mod'
# Set initial_model_relax_num_steps to 50
# Set load_model_filename to 'planet_create_0.2_Mj_5.0_Rj.mod'
# Set save_model_filename to 'planet_evolve_0.2_Mj_5.0_Rj.mod'
# Set mesh_delta_coeff to 1d0
# Set irradiation_flux to 5d4
# Set column_depth_for_irradiation to 5d2
# Set irradiation_flux to 5d4
# Set column_depth_for_irradiation to 5d2
# gfortran -fopenmp -o ../star  run_star_extras.o run_star.o  run.o  -L/Users/Emily/mesa-r24.03.1/lib -lstar -lgyre -lionization -latm -lcolors -lturb -lstar_data -lnet -leos -lkap -lrates -lneu -lchem -linterp_2d -linterp_1d -lnum -lauto_diff -lhdf5io -lmtx -lconst -lmath -lutils `mesasdk_crmath_link` `mesasdk_lapack95_link` `mesasdk_lapack_link` `mesasdk_blas_link` `mesasdk_hdf5_link`  `mesasdk_pgplot_link` -lz

# %%
def update_radius(m, rold, rnew):
    """
    m in Mj, rnew in Rj
    Assumes that this will be run from within the relevant model folder
    """
    
    #edit inlists
    old_create_model_filename = "planet_create_{0}_Mj_{1}_Rj.mod".format(m, rold)
    old_evolve_model_filename = "planet_evolve_{0}_Mj_{1}_Rj.mod".format(m, rold)
    
    create_model_filename = "planet_create_{0}_Mj_{1}_Rj.mod".format(m, rnew)
    evolve_model_filename = "planet_evolve_{0}_Mj_{1}_Rj.mod".format(m, rnew)

    inlist_create = mh.Inlist('./inlist_create')
    inlist_evolve = mh.Inlist('./inlist_evolve')

    #edit inlist_create options
    inlist_create.set_option('mass_in_gm_for_create_initial_model', m*mJtoGrams)
    inlist_create.set_option('radius_in_cm_for_create_initial_model', rnew*rJtoCm)
    inlist_create.set_option('save_model_filename', create_model_filename)
    

    #edit inlist_evolve options
    inlist_evolve.set_option('load_model_filename', create_model_filename)
    inlist_evolve.set_option('save_model_filename', evolve_model_filename)
    
    # edit rn script
    f = open('./rn', 'r')
    g = f.read()
    f.close()

    g = g.replace(old_create_model_filename, create_model_filename)
    g = g.replace(old_evolve_model_filename, evolve_model_filename)
    
    h = open('./rn_temp', 'w')
    h.write(g)
    h.close()
    shutil.copyfile('./rn_temp','./rn')
    
    return

# %%
pwd
# Out:
# '/Users/Emily/Documents/astro/giant_planets/MESAtests/reproducePaxton+2011fig18'

# %%
# need to try stepping through R values until code runs
for i, m in enumerate(Minit):
    os.chdir('/Users/Emily/Documents/astro/giant_planets/MESAtests/reproducePaxton+2011fig18')
    
    print("")
    print("m is {0} Mj".format(m))
    os.system('pwd')
    os.chdir('./Minit={0}Mj/'.format(m))
    os.system('pwd')

    print("r is {0} Rj".format(Rinit[0]))
    create_model_filename = "planet_create_{0}_Mj_{1}_Rj.mod".format(m, Rinit[0])
    evolve_model_filename = "planet_evolve_{0}_Mj_{1}_Rj.mod".format(m, Rinit[0])

    os.system('./rn')

    #test if "create" and "evolve" models exist, indicating success
    test_create = os.path.isfile(create_model_filename)
    test_evolve = os.path.isfile(evolve_model_filename)

    print("test_create is {0} and test_evolve is {1}".format(test_create, test_evolve))

    if test_create is True and test_evolve is True:
        #success, no need to try further r values
        continue
    else:
        print("model did not converge; stepping through decreasing radii")
        for j, r in enumerate(Rinit[:-1]):
            os.system('rm ./LOGS/*')
            os.system('rm ./photos/*')

            print("trying at new radius {0} Rj".format(Rinit[j+1]))
            update_radius(m, r, Rinit[j+1])
            create_model_filename = "planet_create_{0}_Mj_{1}_Rj.mod".format(m, Rinit[j+1])
            evolve_model_filename = "planet_evolve_{0}_Mj_{1}_Rj.mod".format(m, Rinit[j+1])

            
            os.system('./rn')
            test_create = os.path.isfile(create_model_filename)
            test_evolve = os.path.isfile(evolve_model_filename)
            
            if test_create is True and test_evolve is True:
                #success, no need to try further r values
                print("test_create is {0} and test_evolve is {1}".format(test_create, test_evolve))
                break
# Out:
# m is 0.2 Mj
# /Users/Emily/Documents/astro/giant_planets/MESAtests/reproducePaxton+2011fig18
# /Users/Emily/Documents/astro/giant_planets/MESAtests/reproducePaxton+2011fig18/Minit=0.2Mj
# r is 5.0 Rj
# DATE: 2024-08-08
# TIME: 13:42:34
# run inlist_create_header
# DATE: 2024-08-08
# TIME: 13:42:34
#  reading user weak rate file /Users/Emily/mesa-r24.03.1/data/rates_data/rate_tables/S13_r_be7_wk_li7.h5
#  version_number r24.03.1
#  read inlist_create
#  create initial model
#                          create initial model iteration           1
#       log10(L/Lsun)=  -2.97569028E+00
#                Mass=   1.77441956E+30
#              Radius=   6.66204450E+10
#
#       log10(L/Lsun)=  -3.07996188E+00
#                Mass=   1.63670084E+30
#              Radius=   6.39715627E+10
#
#       log10(L/Lsun)=  -2.25626134E+00
#                Mass=   1.63841424E+30
#              Radius=   6.61941755E+10
#
#                          create initial model iteration           2
#       log10(L/Lsun)=  -2.56461749E+00
#                Mass=   1.19204390E+30
#              Radius=   5.72178922E+10
#
#       log10(L/Lsun)=  -2.63343829E+00
#                Mass=   1.09893476E+30
#              Radius=   5.49958120E+10
#
#       log10(L/Lsun)=  -2.63540773E+00
#                Mass=   1.10054436E+30
#              Radius=   5.48049260E+10
#
#                          create initial model iteration           3
#       log10(L/Lsun)=  -3.06692874E+00
#                Mass=   8.50872124E+29
#              Radius=   4.73374492E+10
#
#       log10(L/Lsun)=  -4.26759142E+00
#                Mass=   7.84826885E+29
#              Radius=   4.60937873E+10
#
#       log10(L/Lsun)=  -4.26932984E+00
#                Mass=   7.86179540E+29
#              Radius=   4.58900573E+10
#
#                          create initial model iteration           4
#       log10(L/Lsun)=  -3.73110931E+00
#                Mass=   6.24740660E+29
#              Radius=   3.86160465E+10
#
#       log10(L/Lsun)=  -4.06312759E+00
#                Mass=   6.76218817E+29
#              Radius=   4.03774131E+10
#
#       log10(L/Lsun)=  -3.72832176E+00
#                Mass=   6.25893190E+29
#              Radius=   3.84745233E+10
#
#                          create initial model iteration           5
#       log10(L/Lsun)=  -3.40571289E+00
#                Mass=   5.68649897E+29
#              Radius=   3.80768603E+10
#
#       log10(L/Lsun)=  -3.63904503E+00
#                Mass=   6.15074223E+29
#              Radius=   3.96921777E+10
#
#       log10(L/Lsun)=  -3.46146918E+00
#                Mass=   5.69664133E+29
#              Radius=   3.79695922E+10
#
#                          create initial model iteration           6
#       log10(L/Lsun)=  -3.28749260E+00
#                Mass=   5.24460931E+29
#              Radius=   3.78274203E+10
#
#       log10(L/Lsun)=  -3.36673353E+00
#                Mass=   5.66798463E+29
#              Radius=   3.93996088E+10
#
#       log10(L/Lsun)=  -3.29058632E+00
#                Mass=   5.25349577E+29
#              Radius=   3.76835050E+10
#
#                          create initial model iteration           7
#       log10(L/Lsun)=  -3.24744475E+00
#                Mass=   5.15890211E+29
#              Radius=   3.86882075E+10
#
#       log10(L/Lsun)=  -3.85814379E+00
#                Mass=   4.77935128E+29
#              Radius=   3.76728854E+10
#
#       log10(L/Lsun)=  -3.84811022E+00
#                Mass=   4.78699608E+29
#              Radius=   3.75259557E+10
#
#                          create initial model iteration           8
#       log10(L/Lsun)=  -3.49760867E+00
#                Mass=   4.48207273E+29
#              Radius=   3.68378874E+10
#
#       log10(L/Lsun)=  -5.13631417E+00
#                Mass=   4.16113033E+29
#              Radius=   3.55803629E+10
#
#       log10(L/Lsun)=  -3.48037089E+00
#                Mass=   4.16745114E+29
#              Radius=   3.53577966E+10
#
#                          create initial model iteration           9
#       log10(L/Lsun)=  -3.45135783E+00
#                Mass=   4.25442747E+29
#              Radius=   3.65412781E+10
#
#       log10(L/Lsun)=  -5.19215723E+00
#                Mass=   3.95297897E+29
#              Radius=   3.52043421E+10
#
#       log10(L/Lsun)=  -5.19357103E+00
#                Mass=   3.95872505E+29
#              Radius=   3.50943434E+10
#
#                          create initial model iteration          10
#       log10(L/Lsun)=  -5.20273788E+00
#                Mass=   3.87411304E+29
#              Radius=   3.55544438E+10
#
#       log10(L/Lsun)=  -5.09853169E+00
#                Mass=   4.16808980E+29
#              Radius=   3.71985398E+10
#
#       log10(L/Lsun)=  -5.20528359E+00
#                Mass=   3.87946696E+29
#              Radius=   3.53684845E+10
#
#                          create initial model iteration          11
#  failed in kap_get get_kap_from_rhoT
#  temp too low in integration
# DATE: 2024-08-08
# TIME: 13:43:25
#
# ******************************************************************
# failed to create planet_create_0.2_Mj_5.0_Rj.mod when running inlist_create_header
# ******************************************************************
#
# test_create is False and test_evolve is False
# model did not converge; stepping through decreasing radii
# trying at new radius 2.0 Rj
# Set mass_in_gm_for_create_initial_model to 3.79625d29
# Set radius_in_cm_for_create_initial_model to 1.42984d10
# Set save_model_filename to 'planet_create_0.2_Mj_2.0_Rj.mod'
# Set load_model_filename to 'planet_create_0.2_Mj_2.0_Rj.mod'
# Set save_model_filename to 'planet_evolve_0.2_Mj_2.0_Rj.mod'
# DATE: 2024-08-08
# TIME: 13:43:25
# run inlist_create_header
# DATE: 2024-08-08
# TIME: 13:43:25
# rm: ./LOGS/*: No such file or directory
# rm: ./photos/*: No such file or directory
#  reading user weak rate file /Users/Emily/mesa-r24.03.1/data/rates_data/rate_tables/S13_r_be7_wk_li7.h5
#  version_number r24.03.1
#  read inlist_create
#  create initial model
#                          create initial model iteration           1
#       log10(L/Lsun)=  -2.97397155E+00
#                Mass=   1.77442181E+30
#              Radius=   6.65519947E+10
#
#       log10(L/Lsun)=  -2.25469962E+00
#                Mass=   1.63672097E+30
#              Radius=   6.64098298E+10
#
#       log10(L/Lsun)=  -2.25614081E+00
#                Mass=   1.63841455E+30
#              Radius=   6.62097459E+10
#
#                          create initial model iteration           2
#       log10(L/Lsun)=  -3.06295083E+00
#                Mass=   1.72343320E+30
#              Radius=   6.33786481E+10
#
#       log10(L/Lsun)=  -2.30541236E+00
#                Mass=   1.59128670E+30
#              Radius=   6.34355639E+10
#
#       log10(L/Lsun)=  -2.30680319E+00
#                Mass=   1.59293878E+30
#              Radius=   6.32468689E+10
#
#                          create initial model iteration           3
#       log10(L/Lsun)=  -3.13170439E+00
#                Mass=   1.67642509E+30
#              Radius=   6.07320488E+10
#
#       log10(L/Lsun)=  -2.35605197E+00
#                Mass=   1.54940181E+30
#              Radius=   6.06328494E+10
#
#       log10(L/Lsun)=  -2.35801828E+00
#                Mass=   1.55101588E+30
#              Radius=   6.03814402E+10
#
#                          create initial model iteration           4
#       log10(L/Lsun)=  -2.33623063E+00
#                Mass=   1.61204923E+30
#              Radius=   5.99705304E+10
#
#       log10(L/Lsun)=  -2.41961352E+00
#                Mass=   1.49129221E+30
#              Radius=   5.76229639E+10
#
#       log10(L/Lsun)=  -2.42147794E+00
#                Mass=   1.49288380E+30
#              Radius=   5.73865677E+10
#
#                          create initial model iteration           5
#       log10(L/Lsun)=  -2.44204851E+00
#                Mass=   1.48876570E+30
#              Radius=   5.58834286E+10
#
#       log10(L/Lsun)=  -2.52866894E+00
#                Mass=   1.37820023E+30
#              Radius=   5.35785540E+10
#
#       log10(L/Lsun)=  -2.52994033E+00
#                Mass=   1.37978594E+30
#              Radius=   5.34216491E+10
#
#                          create initial model iteration           6
#       log10(L/Lsun)=  -2.53806789E+00
#                Mass=   1.39376812E+30
#              Radius=   5.22809785E+10
#
#       log10(L/Lsun)=  -2.62061011E+00
#                Mass=   1.29116816E+30
#              Radius=   5.00738253E+10
#
#       log10(L/Lsun)=  -2.62196676E+00
#                Mass=   1.29274319E+30
#              Radius=   4.99283422E+10
#
#                          create initial model iteration           7
#       log10(L/Lsun)=  -2.71253585E+00
#                Mass=   1.20616822E+30
#              Radius=   4.66560743E+10
#
#       log10(L/Lsun)=  -2.63490209E+00
#                Mass=   1.30109798E+30
#              Radius=   4.87670813E+10
#
#       log10(L/Lsun)=  -2.71398053E+00
#                Mass=   1.20773178E+30
#              Radius=   4.65217459E+10
#
#                          create initial model iteration           8
#       log10(L/Lsun)=  -2.80658383E+00
#                Mass=   1.12290225E+30
#              Radius=   4.33385267E+10
#
#       log10(L/Lsun)=  -2.73198623E+00
#                Mass=   1.21041642E+30
#              Radius=   4.53337163E+10
#
#       log10(L/Lsun)=  -2.80806268E+00
#                Mass=   1.12443361E+30
#              Radius=   4.32152221E+10
#
#                          create initial model iteration           9
#       log10(L/Lsun)=  -2.90597649E+00
#                Mass=   1.04267518E+30
#              Radius=   4.01644155E+10
#
#       log10(L/Lsun)=  -2.82997744E+00
#                Mass=   1.12309830E+30
#              Radius=   4.20336381E+10
#
#       log10(L/Lsun)=  -2.90736651E+00
#                Mass=   1.04415344E+30
#              Radius=   4.00522493E+10
#
#                          create initial model iteration          10
#       log10(L/Lsun)=  -3.13374334E+00
#                Mass=   9.66661282E+29
#              Radius=   3.71663441E+10
#
#       log10(L/Lsun)=  -2.93234287E+00
#                Mass=   1.04038294E+30
#              Radius=   3.89103695E+10
#
#       log10(L/Lsun)=  -3.13648898E+00
#                Mass=   9.68078005E+29
#              Radius=   3.70660068E+10
#
#                          create initial model iteration          11
#       log10(L/Lsun)=  -3.16138951E+00
#                Mass=   9.63088090E+29
#              Radius=   3.59797411E+10
#
#       log10(L/Lsun)=  -3.36937242E+00
#                Mass=   8.95781885E+29
#              Radius=   3.42105599E+10
#
#       log10(L/Lsun)=  -3.21351636E+00
#                Mass=   8.97133362E+29
#              Radius=   3.41387610E+10
#
#                          create initial model iteration          12
#       log10(L/Lsun)=  -3.23499492E+00
#                Mass=   8.87592325E+29
#              Radius=   3.29594869E+10
#
#       log10(L/Lsun)=  -4.55852327E+00
#                Mass=   8.26648252E+29
#              Radius=   3.14753700E+10
#
#       log10(L/Lsun)=  -4.55941379E+00
#                Mass=   8.27958883E+29
#              Radius=   3.13885651E+10
#
#                          create initial model iteration          13
#       log10(L/Lsun)=  -4.73145092E+00
#                Mass=   7.61363286E+29
#              Radius=   2.89145920E+10
#
#       log10(L/Lsun)=  -4.60956468E+00
#                Mass=   8.16109622E+29
#              Radius=   3.02832368E+10
#
#       log10(L/Lsun)=  -4.73229601E+00
#                Mass=   7.62669016E+29
#              Radius=   2.88367165E+10
#
#                          create initial model iteration          14
#       log10(L/Lsun)=  -4.72220140E+00
#                Mass=   6.98978216E+29
#              Radius=   2.65455387E+10
#
#       log10(L/Lsun)=  -4.79400455E+00
#                Mass=   7.47745481E+29
#              Radius=   2.77631204E+10
#
#       log10(L/Lsun)=  -4.72225273E+00
#                Mass=   7.00322018E+29
#              Radius=   2.64796216E+10
#
#                          create initial model iteration          15
#       log10(L/Lsun)=  -4.56387319E+00
#                Mass=   6.87458745E+29
#              Radius=   2.54807489E+10
#
#       log10(L/Lsun)=  -4.08743150E+00
#                Mass=   6.43957283E+29
#              Radius=   2.43294949E+10
#
#       log10(L/Lsun)=  -4.08843512E+00
#                Mass=   6.45369525E+29
#              Radius=   2.42686603E+10
#
#                          create initial model iteration          16
#       log10(L/Lsun)=  -4.02079428E+00
#                Mass=   6.23576209E+29
#              Radius=   2.30923022E+10
#
#       log10(L/Lsun)=  -3.90232449E+00
#                Mass=   5.85051540E+29
#              Radius=   2.20729122E+10
#
#       log10(L/Lsun)=  -3.90357048E+00
#                Mass=   5.86570019E+29
#              Radius=   2.20168516E+10
#
#                          create initial model iteration          17
#       log10(L/Lsun)=  -3.90078445E+00
#                Mass=   5.64361473E+29
#              Radius=   2.08899460E+10
#
#       log10(L/Lsun)=  -4.61704684E+00
#                Mass=   5.29928649E+29
#              Radius=   2.00765358E+10
#
#       log10(L/Lsun)=  -4.61190170E+00
#                Mass=   5.31541081E+29
#              Radius=   2.00242920E+10
#
#                          create initial model iteration          18
#       log10(L/Lsun)=  -5.68178973E+00
#                Mass=   4.89741633E+29
#              Radius=   1.84430638E+10
#
#       log10(L/Lsun)=  -4.47633736E+00
#                Mass=   5.21039816E+29
#              Radius=   1.92197782E+10
#
#       log10(L/Lsun)=  -5.68251633E+00
#                Mass=   4.91409488E+29
#              Radius=   1.83968977E+10
#
#                          create initial model iteration          19
#       log10(L/Lsun)=  -5.84760530E+00
#                Mass=   4.50913219E+29
#              Radius=   1.69506510E+10
#
#       log10(L/Lsun)=  -5.75197579E+00
#                Mass=   4.79092979E+29
#              Radius=   1.76536295E+10
#
#       log10(L/Lsun)=  -5.84825996E+00
#                Mass=   4.52603035E+29
#              Radius=   1.69093210E+10
#
#                          create initial model iteration          20
#  failed in kap_get get_kap_from_rhoT
#  temp too low in integration
# DATE: 2024-08-08
# TIME: 13:45:01
#
# ******************************************************************
# failed to create planet_create_0.2_Mj_2.0_Rj.mod when running inlist_create_header
# ******************************************************************
#
# trying at new radius 1.5 Rj
# Set mass_in_gm_for_create_initial_model to 3.79625d29
# Set radius_in_cm_for_create_initial_model to 1.07238d10
# Set save_model_filename to 'planet_create_0.2_Mj_1.5_Rj.mod'
# Set load_model_filename to 'planet_create_0.2_Mj_1.5_Rj.mod'
# Set save_model_filename to 'planet_evolve_0.2_Mj_1.5_Rj.mod'
# DATE: 2024-08-08
# TIME: 13:45:01
# run inlist_create_header
# DATE: 2024-08-08
# TIME: 13:45:01
# rm: ./LOGS/*: No such file or directory
# rm: ./photos/*: No such file or directory
#  reading user weak rate file /Users/Emily/mesa-r24.03.1/data/rates_data/rate_tables/S13_r_be7_wk_li7.h5
#  version_number r24.03.1
#  read inlist_create
#  create initial model
#                          create initial model iteration           1
#       log10(L/Lsun)=  -2.98461791E+00
#                Mass=   1.77442193E+30
#              Radius=   6.64718791E+10
#
#       log10(L/Lsun)=  -2.25640717E+00
#                Mass=   1.63671704E+30
#              Radius=   6.61636276E+10
#
#       log10(L/Lsun)=  -2.25784196E+00
#                Mass=   1.63840685E+30
#              Radius=   6.59651791E+10
#
#                          create initial model iteration           2
#       log10(L/Lsun)=  -3.05428249E+00
#                Mass=   1.72498268E+30
#              Radius=   6.35308232E+10
#
#       log10(L/Lsun)=  -2.30489937E+00
#                Mass=   1.59271662E+30
#              Radius=   6.34539156E+10
#
#       log10(L/Lsun)=  -2.30618658E+00
#                Mass=   1.59437280E+30
#              Radius=   6.32762664E+10
#
#                          create initial model iteration           3
#       log10(L/Lsun)=  -3.13025635E+00
#                Mass=   1.68189394E+30
#              Radius=   6.08416885E+10
#
#       log10(L/Lsun)=  -2.35274371E+00
#                Mass=   1.55446134E+30
#              Radius=   6.07287043E+10
#
#       log10(L/Lsun)=  -2.35407684E+00
#                Mass=   1.55607899E+30
#              Radius=   6.05504177E+10
#
#                          create initial model iteration           4
#       log10(L/Lsun)=  -2.32080678E+00
#                Mass=   1.63756516E+30
#              Radius=   6.03815164E+10
#
#       log10(L/Lsun)=  -2.40263559E+00
#                Mass=   1.51495204E+30
#              Radius=   5.80689116E+10
#
#       log10(L/Lsun)=  -2.40392052E+00
#                Mass=   1.51653484E+30
#              Radius=   5.79005486E+10
#
#                          create initial model iteration           5
#       log10(L/Lsun)=  -2.39595635E+00
#                Mass=   1.55442858E+30
#              Radius=   5.71122487E+10
#
#       log10(L/Lsun)=  -2.48189751E+00
#                Mass=   1.43923629E+30
#              Radius=   5.47556623E+10
#
#       log10(L/Lsun)=  -2.48311810E+00
#                Mass=   1.44080342E+30
#              Radius=   5.45975895E+10
#
#                          create initial model iteration           6
#       log10(L/Lsun)=  -2.47969532E+00
#                Mass=   1.46907981E+30
#              Radius=   5.37213829E+10
#
#       log10(L/Lsun)=  -2.56589827E+00
#                Mass=   1.36136158E+30
#              Radius=   5.14683865E+10
#
#       log10(L/Lsun)=  -2.56714580E+00
#                Mass=   1.36291289E+30
#              Radius=   5.13211667E+10
#
#                          create initial model iteration           7
#       log10(L/Lsun)=  -2.64956001E+00
#                Mass=   1.28606334E+30
#              Radius=   4.82911676E+10
#
#       log10(L/Lsun)=  -2.56687846E+00
#                Mass=   1.38676839E+30
#              Radius=   5.04544392E+10
#
#       log10(L/Lsun)=  -2.65085895E+00
#                Mass=   1.28758816E+30
#              Radius=   4.81552182E+10
#
#                          create initial model iteration           8
#       log10(L/Lsun)=  -2.73226888E+00
#                Mass=   1.21346026E+30
#              Radius=   4.52321445E+10
#
#       log10(L/Lsun)=  -2.65363976E+00
#                Mass=   1.30740507E+30
#              Radius=   4.73081786E+10
#
#       log10(L/Lsun)=  -2.73361816E+00
#                Mass=   1.21494194E+30
#              Radius=   4.51075456E+10
#
#                          create initial model iteration           9
#       log10(L/Lsun)=  -2.73927915E+00
#                Mass=   1.23110672E+30
#              Radius=   4.42880979E+10
#
#       log10(L/Lsun)=  -2.81524633E+00
#                Mass=   1.14358843E+30
#              Radius=   4.23109735E+10
#
#       log10(L/Lsun)=  -2.81660798E+00
#                Mass=   1.14500690E+30
#              Radius=   4.21976476E+10
#
#                          create initial model iteration          10
#       log10(L/Lsun)=  -2.89957856E+00
#                Mass=   1.07732684E+30
#              Radius=   3.95586768E+10
#
#       log10(L/Lsun)=  -2.82373025E+00
#                Mass=   1.15877602E+30
#              Radius=   4.14307023E+10
#
#       log10(L/Lsun)=  -2.90091809E+00
#                Mass=   1.07865876E+30
#              Radius=   3.94562895E+10
#
#                          create initial model iteration          11
#       log10(L/Lsun)=  -2.98737373E+00
#                Mass=   1.01543366E+30
#              Radius=   3.69840667E+10
#
#       log10(L/Lsun)=  -2.90808956E+00
#                Mass=   1.09117159E+30
#              Radius=   3.87643729E+10
#
#       log10(L/Lsun)=  -2.98849373E+00
#                Mass=   1.01666648E+30
#              Radius=   3.68920890E+10
#
#                          create initial model iteration          12
#       log10(L/Lsun)=  -3.19224505E+00
#                Mass=   9.57642326E+29
#              Radius=   3.45600291E+10
#
#       log10(L/Lsun)=  -2.99449643E+00
#                Mass=   1.02792283E+30
#              Radius=   3.62704830E+10
#
#       log10(L/Lsun)=  -3.19498411E+00
#                Mass=   9.58781150E+29
#              Radius=   3.44791374E+10
#
#                          create initial model iteration          13
#       log10(L/Lsun)=  -3.57091767E+00
#                Mass=   9.03510243E+29
#              Radius=   3.22377689E+10
#
#       log10(L/Lsun)=  -3.21328623E+00
#                Mass=   9.68382928E+29
#              Radius=   3.39326771E+10
#
#       log10(L/Lsun)=  -3.57325702E+00
#                Mass=   9.04577563E+29
#              Radius=   3.21651282E+10
#
#                          create initial model iteration          14
#       log10(L/Lsun)=  -4.57692011E+00
#                Mass=   8.48191037E+29
#              Radius=   3.00100243E+10
#
#       log10(L/Lsun)=  -3.24659072E+00
#                Mass=   9.07421577E+29
#              Radius=   3.13732552E+10
#
#       log10(L/Lsun)=  -3.32168120E+00
#                Mass=   8.49225575E+29
#              Radius=   2.95428132E+10
#
#                          create initial model iteration          15
#       log10(L/Lsun)=  -4.53472498E+00
#                Mass=   6.99127006E+29
#              Radius=   2.56011639E+10
#
#       log10(L/Lsun)=  -4.83391621E+00
#                Mass=   7.46060539E+29
#              Radius=   2.68061445E+10
#
#       log10(L/Lsun)=  -4.53622188E+00
#                Mass=   7.00412995E+29
#              Radius=   2.55405214E+10
#
#                          create initial model iteration          16
#       log10(L/Lsun)=  -4.60345922E+00
#                Mass=   7.05769620E+29
#              Radius=   2.50031531E+10
#
#       log10(L/Lsun)=  -4.21890183E+00
#                Mass=   6.62987900E+29
#              Radius=   2.38633269E+10
#
#       log10(L/Lsun)=  -4.21965448E+00
#                Mass=   6.64324648E+29
#              Radius=   2.38071544E+10
#
#                          create initial model iteration          17
#       log10(L/Lsun)=  -4.06050234E+00
#                Mass=   6.26279734E+29
#              Radius=   2.21335683E+10
#
#       log10(L/Lsun)=  -4.29803281E+00
#                Mass=   6.65157372E+29
#              Radius=   2.31860795E+10
#
#       log10(L/Lsun)=  -4.06162765E+00
#                Mass=   6.27694993E+29
#              Radius=   2.20817753E+10
#
#                          create initial model iteration          18
#       log10(L/Lsun)=  -3.98947756E+00
#                Mass=   5.89869664E+29
#              Radius=   2.04465840E+10
#
#       log10(L/Lsun)=  -4.06072612E+00
#                Mass=   6.25312777E+29
#              Radius=   2.13948405E+10
#
#       log10(L/Lsun)=  -3.99058945E+00
#                Mass=   5.91386643E+29
#              Radius=   2.03991195E+10
#
#                          create initial model iteration          19
#       log10(L/Lsun)=  -4.93746653E+00
#                Mass=   5.55223274E+29
#              Radius=   1.89193353E+10
#
#       log10(L/Lsun)=  -5.46274221E+00
#                Mass=   5.87803430E+29
#              Radius=   1.97736061E+10
#
#       log10(L/Lsun)=  -4.93151477E+00
#                Mass=   5.56846530E+29
#              Radius=   1.88756036E+10
#
#                          create initial model iteration          20
#       log10(L/Lsun)=  -4.90860326E+00
#                Mass=   5.53457650E+29
#              Radius=   1.82232117E+10
#
#       log10(L/Lsun)=  -5.70677697E+00
#                Mass=   5.23318072E+29
#              Radius=   1.74701945E+10
#
#       log10(L/Lsun)=  -5.70749043E+00
#                Mass=   5.25041194E+29
#              Radius=   1.74315924E+10
#
#                          create initial model iteration          21
#       log10(L/Lsun)=  -5.75405618E+00
#                Mass=   5.23554465E+29
#              Radius=   1.68599235E+10
#
#       log10(L/Lsun)=  -5.84632086E+00
#                Mass=   4.95601537E+29
#              Radius=   1.61821462E+10
#
#       log10(L/Lsun)=  -5.84691415E+00
#                Mass=   4.97408743E+29
#              Radius=   1.61477708E+10
#
#                          create initial model iteration          22
#  failed in kap_get get_kap_from_rhoT
#  temp too low in integration
# DATE: 2024-08-08
# TIME: 13:46:56
#
# ******************************************************************
# failed to create planet_create_0.2_Mj_1.5_Rj.mod when running inlist_create_header
# ******************************************************************
#
# trying at new radius 1.0 Rj
# Set mass_in_gm_for_create_initial_model to 3.79625d29
# Set radius_in_cm_for_create_initial_model to 7.1492d9
# Set save_model_filename to 'planet_create_0.2_Mj_1.0_Rj.mod'
# Set load_model_filename to 'planet_create_0.2_Mj_1.0_Rj.mod'
# Set save_model_filename to 'planet_evolve_0.2_Mj_1.0_Rj.mod'
# DATE: 2024-08-08
# TIME: 13:46:56
# run inlist_create_header
# DATE: 2024-08-08
# TIME: 13:46:56
# rm: ./LOGS/*: No such file or directory
# rm: ./photos/*: No such file or directory
#  reading user weak rate file /Users/Emily/mesa-r24.03.1/data/rates_data/rate_tables/S13_r_be7_wk_li7.h5
#  version_number r24.03.1
#  read inlist_create
#  create initial model
#                          create initial model iteration           1
#       log10(L/Lsun)=  -2.97902478E+00
#                Mass=   1.77441621E+30
#              Radius=   6.65777735E+10
#
#       log10(L/Lsun)=  -2.25538606E+00
#                Mass=   1.63671624E+30
#              Radius=   6.63170037E+10
#
#       log10(L/Lsun)=  -2.25682025E+00
#                Mass=   1.63841220E+30
#              Radius=   6.61174940E+10
#
#                          create initial model iteration           2
#       log10(L/Lsun)=  -3.04955607E+00
#                Mass=   1.72814373E+30
#              Radius=   6.36068723E+10
#
#       log10(L/Lsun)=  -2.30299093E+00
#                Mass=   1.59563584E+30
#              Radius=   6.35201078E+10
#
#       log10(L/Lsun)=  -2.30437617E+00
#                Mass=   1.59728951E+30
#              Radius=   6.33312942E+10
#
#                          create initial model iteration           3
#       log10(L/Lsun)=  -3.12929309E+00
#                Mass=   1.68515470E+30
#              Radius=   6.09044027E+10
#
#       log10(L/Lsun)=  -2.35069628E+00
#                Mass=   1.55747496E+30
#              Radius=   6.07852283E+10
#
#       log10(L/Lsun)=  -2.35203286E+00
#                Mass=   1.55908996E+30
#              Radius=   6.06069505E+10
#
#                          create initial model iteration           4
#       log10(L/Lsun)=  -2.31713700E+00
#                Mass=   1.64348063E+30
#              Radius=   6.04917288E+10
#
#       log10(L/Lsun)=  -2.39874235E+00
#                Mass=   1.52043341E+30
#              Radius=   5.81720328E+10
#
#       log10(L/Lsun)=  -2.40003089E+00
#                Mass=   1.52201274E+30
#              Radius=   5.80036265E+10
#
#                          create initial model iteration           5
#       log10(L/Lsun)=  -2.38696316E+00
#                Mass=   1.56907331E+30
#              Radius=   5.72789854E+10
#
#       log10(L/Lsun)=  -2.47151532E+00
#                Mass=   1.45285725E+30
#              Radius=   5.50150721E+10
#
#       log10(L/Lsun)=  -2.47273261E+00
#                Mass=   1.45441823E+30
#              Radius=   5.48568047E+10
#
#                          create initial model iteration           6
#       log10(L/Lsun)=  -2.45982100E+00
#                Mass=   1.49637105E+30
#              Radius=   5.41775052E+10
#
#       log10(L/Lsun)=  -2.54594627E+00
#                Mass=   1.38675832E+30
#              Radius=   5.19639916E+10
#
#       log10(L/Lsun)=  -2.54715997E+00
#                Mass=   1.38829156E+30
#              Radius=   5.18162491E+10
#
#                          create initial model iteration           7
#       log10(L/Lsun)=  -2.53616144E+00
#                Mass=   1.42545586E+30
#              Radius=   5.12016138E+10
#
#       log10(L/Lsun)=  -2.62080260E+00
#                Mass=   1.32217569E+30
#              Radius=   4.90154251E+10
#
#       log10(L/Lsun)=  -2.62204731E+00
#                Mass=   1.32367740E+30
#              Radius=   4.88786434E+10
#
#                          create initial model iteration           8
#       log10(L/Lsun)=  -2.69563392E+00
#                Mass=   1.25865536E+30
#              Radius=   4.61619448E+10
#
#       log10(L/Lsun)=  -2.61441824E+00
#                Mass=   1.35581645E+30
#              Radius=   4.82681861E+10
#
#       log10(L/Lsun)=  -2.69690783E+00
#                Mass=   1.26010761E+30
#              Radius=   4.60364422E+10
#
#                          create initial model iteration           9
#       log10(L/Lsun)=  -2.69105765E+00
#                Mass=   1.28938937E+30
#              Radius=   4.54777942E+10
#
#       log10(L/Lsun)=  -2.76933116E+00
#                Mass=   1.19805511E+30
#              Radius=   4.34536710E+10
#
#       log10(L/Lsun)=  -2.77062141E+00
#                Mass=   1.19943244E+30
#              Radius=   4.33394552E+10
#
#                          create initial model iteration          10
#       log10(L/Lsun)=  -2.84204877E+00
#                Mass=   1.14080255E+30
#              Radius=   4.09139301E+10
#
#       log10(L/Lsun)=  -2.76560756E+00
#                Mass=   1.22667369E+30
#              Radius=   4.28493310E+10
#
#       log10(L/Lsun)=  -2.84331880E+00
#                Mass=   1.14208065E+30
#              Radius=   4.08106336E+10
#
#                          create initial model iteration          11
#       log10(L/Lsun)=  -2.91407306E+00
#                Mass=   1.08752987E+30
#              Radius=   3.85591674E+10
#
#       log10(L/Lsun)=  -2.83753490E+00
#                Mass=   1.16829582E+30
#              Radius=   4.04066091E+10
#
#       log10(L/Lsun)=  -2.91529796E+00
#                Mass=   1.08868900E+30
#              Radius=   3.84659454E+10
#
#                          create initial model iteration          12
#       log10(L/Lsun)=  -2.98583085E+00
#                Mass=   1.03845676E+30
#              Radius=   3.63874108E+10
#
#       log10(L/Lsun)=  -2.90760922E+00
#                Mass=   1.11444371E+30
#              Radius=   3.81541419E+10
#
#       log10(L/Lsun)=  -2.98697783E+00
#                Mass=   1.03949736E+30
#              Radius=   3.63032568E+10
#
#                          create initial model iteration          13
#       log10(L/Lsun)=  -3.05974613E+00
#                Mass=   9.93295565E+29
#              Radius=   3.43658422E+10
#
#       log10(L/Lsun)=  -2.97690683E+00
#                Mass=   1.06476961E+30
#              Radius=   3.60747784E+10
#
#       log10(L/Lsun)=  -3.06075465E+00
#                Mass=   9.94233963E+29
#              Radius=   3.42896225E+10
#
#                          create initial model iteration          14
#       log10(L/Lsun)=  -3.23510302E+00
#                Mass=   9.51071335E+29
#              Radius=   3.24483669E+10
#
#       log10(L/Lsun)=  -3.04752715E+00
#                Mass=   1.01804667E+30
#              Radius=   3.41166502E+10
#
#       log10(L/Lsun)=  -3.23754727E+00
#                Mass=   9.51932651E+29
#              Radius=   3.23799833E+10
#
#                          create initial model iteration          15
#       log10(L/Lsun)=  -3.26944595E+00
#                Mass=   9.73289925E+29
#              Radius=   3.22691787E+10
#
#       log10(L/Lsun)=  -3.26918027E+00
#                Mass=   9.10830244E+29
#              Radius=   3.04995177E+10
#
#       log10(L/Lsun)=  -3.27052590E+00
#                Mass=   9.11641801E+29
#              Radius=   3.04348929E+10
#
#                          create initial model iteration          16
#       log10(L/Lsun)=  -3.44012949E+00
#                Mass=   8.64035488E+29
#              Radius=   2.83814805E+10
#
#       log10(L/Lsun)=  -3.29055760E+00
#                Mass=   9.21205317E+29
#              Radius=   3.00661812E+10
#
#       log10(L/Lsun)=  -3.44504761E+00
#                Mass=   8.64853005E+29
#              Radius=   2.83229989E+10
#
#                          create initial model iteration          17
#       log10(L/Lsun)=  -4.72777085E+00
#                Mass=   8.17125345E+29
#              Radius=   2.67975785E+10
#
#       log10(L/Lsun)=  -3.48702559E+00
#                Mass=   8.68806803E+29
#              Radius=   2.78331400E+10
#
#       log10(L/Lsun)=  -4.72849803E+00
#                Mass=   8.17994507E+29
#              Radius=   2.67396091E+10
#
#                          create initial model iteration          18
#       log10(L/Lsun)=  -4.82035545E+00
#                Mass=   7.91146241E+29
#              Radius=   2.54086628E+10
#
#       log10(L/Lsun)=  -4.69898556E+00
#                Mass=   8.38887717E+29
#              Radius=   2.66782613E+10
#
#       log10(L/Lsun)=  -4.82102748E+00
#                Mass=   7.92051472E+29
#              Radius=   2.53557991E+10
#
#                          create initial model iteration          19
#       log10(L/Lsun)=  -4.94812066E+00
#                Mass=   7.55764243E+29
#              Radius=   2.37925122E+10
#
#       log10(L/Lsun)=  -4.82645784E+00
#                Mass=   7.98830105E+29
#              Radius=   2.49502284E+10
#
#       log10(L/Lsun)=  -4.94872111E+00
#                Mass=   7.56762982E+29
#              Radius=   2.37425493E+10
#
#                          create initial model iteration          20
#       log10(L/Lsun)=  -4.89112733E+00
#                Mass=   7.20191626E+29
#              Radius=   2.21378815E+10
#
#       log10(L/Lsun)=  -4.97063915E+00
#                Mass=   7.58747915E+29
#              Radius=   2.32125425E+10
#
#       log10(L/Lsun)=  -4.88709747E+00
#                Mass=   7.21315692E+29
#              Radius=   2.20910887E+10
#
#                          create initial model iteration          21
#       log10(L/Lsun)=  -4.35232620E+00
#                Mass=   6.82097191E+29
#              Radius=   2.03812785E+10
#
#       log10(L/Lsun)=  -4.81105953E+00
#                Mass=   7.16415381E+29
#              Radius=   2.13706140E+10
#
#       log10(L/Lsun)=  -4.35060732E+00
#                Mass=   6.83383309E+29
#              Radius=   2.03384977E+10
#
#                          create initial model iteration          22
#       log10(L/Lsun)=  -4.16837365E+00
#                Mass=   6.40725996E+29
#              Radius=   1.85690871E+10
#
#       log10(L/Lsun)=  -4.28962363E+00
#                Mass=   6.71434839E+29
#              Radius=   1.94324568E+10
#
#       log10(L/Lsun)=  -4.16840145E+00
#                Mass=   6.42196782E+29
#              Radius=   1.85311548E+10
#
#                          create initial model iteration          23
#       log10(L/Lsun)=  -5.55606916E+00
#                Mass=   6.29272136E+29
#              Radius=   1.76722551E+10
#
#       log10(L/Lsun)=  -5.30190739E+00
#                Mass=   6.01236984E+29
#              Radius=   1.69257847E+10
#
#       log10(L/Lsun)=  -5.26420013E+00
#                Mass=   6.02889557E+29
#              Radius=   1.68927628E+10
#
#                          create initial model iteration          24
#       log10(L/Lsun)=  -5.82385482E+00
#                Mass=   5.66559442E+29
#              Radius=   1.54558833E+10
#
#       log10(L/Lsun)=  -5.73391927E+00
#                Mass=   5.92556213E+29
#              Radius=   1.61011817E+10
#
#       log10(L/Lsun)=  -5.82423308E+00
#                Mass=   5.68372589E+29
#              Radius=   1.54278295E+10
#
#                          create initial model iteration          25
#       log10(L/Lsun)=  -5.98972766E+00
#                Mass=   5.37241336E+29
#              Radius=   1.41994630E+10
#
#       log10(L/Lsun)=  -5.89916382E+00
#                Mass=   5.61366817E+29
#              Radius=   1.47586995E+10
#
#       log10(L/Lsun)=  -5.98999151E+00
#                Mass=   5.39190963E+29
#              Radius=   1.41756536E+10
#
#                          create initial model iteration          26
#  failed in kap_get get_kap_from_rhoT
#  temp too low in integration
# DATE: 2024-08-08
# TIME: 13:49:47
#
# ******************************************************************
# failed to create planet_create_0.2_Mj_1.0_Rj.mod when running inlist_create_header
# ******************************************************************
#
# trying at new radius 0.75 Rj
# Set mass_in_gm_for_create_initial_model to 3.79625d29
# Set radius_in_cm_for_create_initial_model to 5.3619d9
# Set save_model_filename to 'planet_create_0.2_Mj_0.75_Rj.mod'
# Set load_model_filename to 'planet_create_0.2_Mj_0.75_Rj.mod'
# Set save_model_filename to 'planet_evolve_0.2_Mj_0.75_Rj.mod'
# DATE: 2024-08-08
# TIME: 13:49:48
# run inlist_create_header
# DATE: 2024-08-08
# TIME: 13:49:48
# rm: ./LOGS/*: No such file or directory
# rm: ./photos/*: No such file or directory
#  reading user weak rate file /Users/Emily/mesa-r24.03.1/data/rates_data/rate_tables/S13_r_be7_wk_li7.h5
#  version_number r24.03.1
#  read inlist_create
#  create initial model
#                          create initial model iteration           1
#       log10(L/Lsun)=  -2.98934206E+00
#                Mass=   1.77442287E+30
#              Radius=   6.65132621E+10
#
#       log10(L/Lsun)=  -2.25598509E+00
#                Mass=   1.63672075E+30
#              Radius=   6.62374827E+10
#
#       log10(L/Lsun)=  -2.25606721E+00
#                Mass=   1.63841345E+30
#              Radius=   6.62100185E+10
#
#                          create initial model iteration           2
#       log10(L/Lsun)=  -3.02387599E+00
#                Mass=   1.76561427E+30
#              Radius=   6.43684834E+10
#
#       log10(L/Lsun)=  -2.28215715E+00
#                Mass=   1.63020701E+30
#              Radius=   6.40947835E+10
#
#       log10(L/Lsun)=  -2.28355776E+00
#                Mass=   1.63185184E+30
#              Radius=   6.39061377E+10
#
#                          create initial model iteration           3
#       log10(L/Lsun)=  -3.09483247E+00
#                Mass=   1.72141199E+30
#              Radius=   6.14545280E+10
#
#       log10(L/Lsun)=  -2.32925377E+00
#                Mass=   1.59098724E+30
#              Radius=   6.13488122E+10
#
#       log10(L/Lsun)=  -2.33005047E+00
#                Mass=   1.59259221E+30
#              Radius=   6.12371702E+10
#
#                          create initial model iteration           4
#       log10(L/Lsun)=  -3.14622946E+00
#                Mass=   1.69444133E+30
#              Radius=   5.92776716E+10
#
#       log10(L/Lsun)=  -2.36760052E+00
#                Mass=   1.56763735E+30
#              Radius=   5.89363156E+10
#
#       log10(L/Lsun)=  -2.36890846E+00
#                Mass=   1.56920058E+30
#              Radius=   5.87681295E+10
#
#                          create initial model iteration           5
#       log10(L/Lsun)=  -2.33352011E+00
#                Mass=   1.65235390E+30
#              Radius=   5.87793856E+10
#
#       log10(L/Lsun)=  -2.41499040E+00
#                Mass=   1.53023572E+30
#              Radius=   5.64790620E+10
#
#       log10(L/Lsun)=  -2.41625598E+00
#                Mass=   1.53175906E+30
#              Radius=   5.63200117E+10
#
#                          create initial model iteration           6
#       log10(L/Lsun)=  -2.40092991E+00
#                Mass=   1.58066016E+30
#              Radius=   5.57158010E+10
#
#       log10(L/Lsun)=  -2.48556060E+00
#                Mass=   1.46517962E+30
#              Radius=   5.34098082E+10
#
#       log10(L/Lsun)=  -2.48621921E+00
#                Mass=   1.46667587E+30
#              Radius=   5.33205905E+10
#
#                          create initial model iteration           7
#       log10(L/Lsun)=  -2.54242089E+00
#                Mass=   1.42055580E+30
#              Radius=   5.09405405E+10
#
#       log10(L/Lsun)=  -2.45690154E+00
#                Mass=   1.53100977E+30
#              Radius=   5.31536412E+10
#
#       log10(L/Lsun)=  -2.54357781E+00
#                Mass=   1.42199554E+30
#              Radius=   5.08017915E+10
#
#                          create initial model iteration           8
#       log10(L/Lsun)=  -2.61480347E+00
#                Mass=   1.35809072E+30
#              Radius=   4.81565409E+10
#
#       log10(L/Lsun)=  -2.52902304E+00
#                Mass=   1.46230228E+30
#              Radius=   5.03304694E+10
#
#       log10(L/Lsun)=  -2.61596019E+00
#                Mass=   1.35947191E+30
#              Radius=   4.80287702E+10
#
#                          create initial model iteration           9
#       log10(L/Lsun)=  -2.68661278E+00
#                Mass=   1.29743818E+30
#              Radius=   4.54950511E+10
#
#       log10(L/Lsun)=  -2.60301733E+00
#                Mass=   1.39577170E+30
#              Radius=   4.75846298E+10
#
#       log10(L/Lsun)=  -2.68778599E+00
#                Mass=   1.29873047E+30
#              Radius=   4.53785401E+10
#
#                          create initial model iteration          10
#       log10(L/Lsun)=  -2.75585755E+00
#                Mass=   1.24058205E+30
#              Radius=   4.30029590E+10
#
#       log10(L/Lsun)=  -2.67518618E+00
#                Mass=   1.33340993E+30
#              Radius=   4.50148234E+10
#
#       log10(L/Lsun)=  -2.75703090E+00
#                Mass=   1.24176978E+30
#              Radius=   4.28974588E+10
#
#                          create initial model iteration          11
#       log10(L/Lsun)=  -2.82260069E+00
#                Mass=   1.18754641E+30
#              Radius=   4.06889210E+10
#
#       log10(L/Lsun)=  -2.74424136E+00
#                Mass=   1.27530381E+30
#              Radius=   4.26222604E+10
#
#       log10(L/Lsun)=  -2.82375680E+00
#                Mass=   1.18861437E+30
#              Radius=   4.05935975E+10
#
#                          create initial model iteration          12
#       log10(L/Lsun)=  -2.80969043E+00
#                Mass=   1.22166198E+30
#              Radius=   4.04124141E+10
#
#       log10(L/Lsun)=  -2.88696669E+00
#                Mass=   1.13855560E+30
#              Radius=   3.85586477E+10
#
#       log10(L/Lsun)=  -2.88808642E+00
#                Mass=   1.13950138E+30
#              Radius=   3.84720862E+10
#
#                          create initial model iteration          13
#       log10(L/Lsun)=  -2.94971863E+00
#                Mass=   1.09357748E+30
#              Radius=   3.66013138E+10
#
#       log10(L/Lsun)=  -2.87215232E+00
#                Mass=   1.17234121E+30
#              Radius=   3.83778042E+10
#
#       log10(L/Lsun)=  -2.95081197E+00
#                Mass=   1.09440605E+30
#              Radius=   3.65220090E+10
#
#                          create initial model iteration          14
#       log10(L/Lsun)=  -2.93250892E+00
#                Mass=   1.12692350E+30
#              Radius=   3.64964011E+10
#
#       log10(L/Lsun)=  -3.01110154E+00
#                Mass=   1.05225423E+30
#              Radius=   3.47877603E+10
#
#       log10(L/Lsun)=  -3.01219588E+00
#                Mass=   1.05299350E+30
#              Radius=   3.47144886E+10
#
#                          create initial model iteration          15
#       log10(L/Lsun)=  -2.99246945E+00
#                Mass=   1.08443849E+30
#              Radius=   3.47322607E+10
#
#       log10(L/Lsun)=  -3.07291427E+00
#                Mass=   1.01372783E+30
#              Radius=   3.30793369E+10
#
#       log10(L/Lsun)=  -3.07396975E+00
#                Mass=   1.01440475E+30
#              Radius=   3.30106657E+10
#
#                          create initial model iteration          16
#       log10(L/Lsun)=  -3.05361517E+00
#                Mass=   1.04369322E+30
#              Radius=   3.30367108E+10
#
#       log10(L/Lsun)=  -3.28976063E+00
#                Mass=   9.77039541E+29
#              Radius=   3.14815351E+10
#
#       log10(L/Lsun)=  -3.29202904E+00
#                Mass=   9.77678225E+29
#              Radius=   3.14172157E+10
#
#                          create initial model iteration          17
#       log10(L/Lsun)=  -3.11610300E+00
#                Mass=   1.00558670E+30
#              Radius=   3.14087638E+10
#
#       log10(L/Lsun)=  -3.30750422E+00
#                Mass=   9.43011416E+29
#              Radius=   2.98217978E+10
#
#       log10(L/Lsun)=  -3.30943173E+00
#                Mass=   9.43643930E+29
#              Radius=   2.97606457E+10
#
#                          create initial model iteration          18
#       log10(L/Lsun)=  -3.33001333E+00
#                Mass=   9.64428271E+29
#              Radius=   2.97249127E+10
#
#       log10(L/Lsun)=  -3.35095165E+00
#                Mass=   9.06414351E+29
#              Radius=   2.80334119E+10
#
#       log10(L/Lsun)=  -3.35276233E+00
#                Mass=   9.07076808E+29
#              Radius=   2.79755350E+10
#
#                          create initial model iteration          19
#       log10(L/Lsun)=  -3.36406543E+00
#                Mass=   9.13234978E+29
#              Radius=   2.75582192E+10
#
#       log10(L/Lsun)=  -3.43739576E+00
#                Mass=   8.60953179E+29
#              Radius=   2.61226043E+10
#
#       log10(L/Lsun)=  -3.43935235E+00
#                Mass=   8.61691549E+29
#              Radius=   2.60662282E+10
#
#                          create initial model iteration          20
#       log10(L/Lsun)=  -4.67914794E+00
#                Mass=   8.68078318E+29
#              Radius=   2.59708258E+10
#
#       log10(L/Lsun)=  -4.79919980E+00
#                Mass=   8.21256673E+29
#              Radius=   2.47194163E+10
#
#       log10(L/Lsun)=  -4.79988578E+00
#                Mass=   8.22103561E+29
#              Radius=   2.46671420E+10
#
#                          create initial model iteration          21
#       log10(L/Lsun)=  -4.80834403E+00
#                Mass=   8.27610835E+29
#              Radius=   2.42322746E+10
#
#       log10(L/Lsun)=  -4.92884429E+00
#                Mass=   7.85846768E+29
#              Radius=   2.31041939E+10
#
#       log10(L/Lsun)=  -4.92950008E+00
#                Mass=   7.86822399E+29
#              Radius=   2.30548677E+10
#
#                          create initial model iteration          22
#       log10(L/Lsun)=  -4.95878596E+00
#                Mass=   7.86617729E+29
#              Radius=   2.24632907E+10
#
#       log10(L/Lsun)=  -5.08166542E+00
#                Mass=   7.49753570E+29
#              Radius=   2.14317907E+10
#
#       log10(L/Lsun)=  -5.08224433E+00
#                Mass=   7.50888226E+29
#              Radius=   2.13860867E+10
#
#                          create initial model iteration          23
#       log10(L/Lsun)=  -4.59732228E+00
#                Mass=   7.10603049E+29
#              Radius=   1.96379809E+10
#
#       log10(L/Lsun)=  -4.97830193E+00
#                Mass=   7.42930248E+29
#              Radius=   2.05718303E+10
#
#       log10(L/Lsun)=  -4.59214898E+00
#                Mass=   7.11925395E+29
#              Radius=   1.95967083E+10
#
#                          create initial model iteration          24
#       log10(L/Lsun)=  -4.41180359E+00
#                Mass=   6.96169919E+29
#              Radius=   1.85711545E+10
#
#       log10(L/Lsun)=  -5.49175137E+00
#                Mass=   6.67543797E+29
#              Radius=   1.77994719E+10
#
#       log10(L/Lsun)=  -5.49237319E+00
#                Mass=   6.69073061E+29
#              Radius=   1.77641513E+10
#
#                          create initial model iteration          25
#       log10(L/Lsun)=  -5.68272198E+00
#                Mass=   6.29918348E+29
#              Radius=   1.61602446E+10
#
#       log10(L/Lsun)=  -5.58801342E+00
#                Mass=   6.56069298E+29
#              Radius=   1.68498209E+10
#
#       log10(L/Lsun)=  -5.68331357E+00
#                Mass=   6.31635308E+29
#              Radius=   1.61303792E+10
#
#                          create initial model iteration          26
#       log10(L/Lsun)=  -5.86955891E+00
#                Mass=   5.93998384E+29
#              Radius=   1.46762572E+10
#
#       log10(L/Lsun)=  -5.78187157E+00
#                Mass=   6.18226876E+29
#              Radius=   1.52652422E+10
#
#       log10(L/Lsun)=  -5.86993666E+00
#                Mass=   5.95890752E+29
#              Radius=   1.46515035E+10
#
#                          create initial model iteration          27
#       log10(L/Lsun)=  -6.04953764E+00
#                Mass=   5.64241987E+29
#              Radius=   1.34365758E+10
#
#       log10(L/Lsun)=  -5.95998389E+00
#                Mass=   5.86659763E+29
#              Radius=   1.39402146E+10
#
#       log10(L/Lsun)=  -6.04976052E+00
#                Mass=   5.66286309E+29
#              Radius=   1.34162043E+10
#
#                          create initial model iteration          28
#  failed in kap_get get_kap_from_rhoT
#  temp too low in integration
# DATE: 2024-08-08
# TIME: 13:52:50
#
# ******************************************************************
# failed to create planet_create_0.2_Mj_0.75_Rj.mod when running inlist_create_header
# ******************************************************************
#
# trying at new radius 0.5 Rj
# Set mass_in_gm_for_create_initial_model to 3.79625d29
# Set radius_in_cm_for_create_initial_model to 3.5746d9
# Set save_model_filename to 'planet_create_0.2_Mj_0.5_Rj.mod'
# Set load_model_filename to 'planet_create_0.2_Mj_0.5_Rj.mod'
# Set save_model_filename to 'planet_evolve_0.2_Mj_0.5_Rj.mod'
# DATE: 2024-08-08
# TIME: 13:52:50
# run inlist_create_header
# DATE: 2024-08-08
# TIME: 13:52:50
# rm: ./LOGS/*: No such file or directory
# rm: ./photos/*: No such file or directory
#  reading user weak rate file /Users/Emily/mesa-r24.03.1/data/rates_data/rate_tables/S13_r_be7_wk_li7.h5
#  version_number r24.03.1
#  read inlist_create
#  create initial model
#                          create initial model iteration           1
#       log10(L/Lsun)=  -2.98479598E+00
#                Mass=   1.77442204E+30
#              Radius=   6.64705679E+10
#
#       log10(L/Lsun)=  -2.25639637E+00
#                Mass=   1.63671722E+30
#              Radius=   6.61635030E+10
#
#       log10(L/Lsun)=  -2.25784755E+00
#                Mass=   1.63840711E+30
#              Radius=   6.59630974E+10
#
#                          create initial model iteration           2
#       log10(L/Lsun)=  -3.05461773E+00
#                Mass=   1.73003974E+30
#              Radius=   6.35985706E+10
#
#       log10(L/Lsun)=  -2.30172603E+00
#                Mass=   1.59738070E+30
#              Radius=   6.35513914E+10
#
#       log10(L/Lsun)=  -2.30435537E+00
#                Mass=   1.59903493E+30
#              Radius=   6.32163433E+10
#
#                          create initial model iteration           3
#       log10(L/Lsun)=  -2.28401029E+00
#                Mass=   1.66216660E+30
#              Radius=   6.27427976E+10
#
#       log10(L/Lsun)=  -2.36557921E+00
#                Mass=   1.53620303E+30
#              Radius=   6.03167853E+10
#
#       log10(L/Lsun)=  -2.36689426E+00
#                Mass=   1.53782377E+30
#              Radius=   6.01390738E+10
#
#                          create initial model iteration           4
#       log10(L/Lsun)=  -2.34845208E+00
#                Mass=   1.59333832E+30
#              Radius=   5.96085183E+10
#
#       log10(L/Lsun)=  -2.43234898E+00
#                Mass=   1.47392662E+30
#              Radius=   5.72951093E+10
#
#       log10(L/Lsun)=  -2.43360103E+00
#                Mass=   1.47552587E+30
#              Radius=   5.71270697E+10
#
#                          create initial model iteration           5
#       log10(L/Lsun)=  -2.41437561E+00
#                Mass=   1.52765167E+30
#              Radius=   5.66181735E+10
#
#       log10(L/Lsun)=  -2.50094700E+00
#                Mass=   1.41433719E+30
#              Radius=   5.42789124E+10
#
#       log10(L/Lsun)=  -2.50217962E+00
#                Mass=   1.41591129E+30
#              Radius=   5.41212604E+10
#
#                          create initial model iteration           6
#       log10(L/Lsun)=  -2.48503068E+00
#                Mass=   1.46220821E+30
#              Radius=   5.35920046E+10
#
#       log10(L/Lsun)=  -2.57087986E+00
#                Mass=   1.35496317E+30
#              Radius=   5.13434256E+10
#
#       log10(L/Lsun)=  -2.57212646E+00
#                Mass=   1.35651683E+30
#              Radius=   5.11963391E+10
#
#                          create initial model iteration           7
#       log10(L/Lsun)=  -2.64001605E+00
#                Mass=   1.29802783E+30
#              Radius=   4.85328977E+10
#
#       log10(L/Lsun)=  -2.55670592E+00
#                Mass=   1.39958888E+30
#              Radius=   5.07034864E+10
#
#       log10(L/Lsun)=  -2.64129862E+00
#                Mass=   1.29954240E+30
#              Radius=   4.83966655E+10
#
#                          create initial model iteration           8
#       log10(L/Lsun)=  -2.62733632E+00
#                Mass=   1.33989275E+30
#              Radius=   4.79549993E+10
#
#       log10(L/Lsun)=  -2.70776183E+00
#                Mass=   1.24379069E+30
#              Radius=   4.58582132E+10
#
#       log10(L/Lsun)=  -2.70906270E+00
#                Mass=   1.24525287E+30
#              Radius=   4.57330069E+10
#
#                          create initial model iteration           9
#       log10(L/Lsun)=  -2.69616066E+00
#                Mass=   1.28316252E+30
#              Radius=   4.53523603E+10
#
#       log10(L/Lsun)=  -2.77418890E+00
#                Mass=   1.19223476E+30
#              Radius=   4.33328613E+10
#
#       log10(L/Lsun)=  -2.77548786E+00
#                Mass=   1.19361770E+30
#              Radius=   4.32187402E+10
#
#                          create initial model iteration          10
#       log10(L/Lsun)=  -2.83932136E+00
#                Mass=   1.14381086E+30
#              Radius=   4.09771952E+10
#
#       log10(L/Lsun)=  -2.76277166E+00
#                Mass=   1.22988623E+30
#              Radius=   4.29162555E+10
#
#       log10(L/Lsun)=  -2.84059630E+00
#                Mass=   1.14508207E+30
#              Radius=   4.08739446E+10
#
#                          create initial model iteration          11
#       log10(L/Lsun)=  -2.82659764E+00
#                Mass=   1.18063735E+30
#              Radius=   4.06665904E+10
#
#       log10(L/Lsun)=  -2.90311121E+00
#                Mass=   1.09906189E+30
#              Radius=   3.88079758E+10
#
#       log10(L/Lsun)=  -2.90432668E+00
#                Mass=   1.10021064E+30
#              Radius=   3.87145617E+10
#
#                          create initial model iteration          12
#       log10(L/Lsun)=  -2.96543736E+00
#                Mass=   1.05797459E+30
#              Radius=   3.68180101E+10
#
#       log10(L/Lsun)=  -2.88798375E+00
#                Mass=   1.13534966E+30
#              Radius=   3.86024108E+10
#
#       log10(L/Lsun)=  -2.96661921E+00
#                Mass=   1.05899848E+30
#              Radius=   3.67335603E+10
#
#                          create initial model iteration          13
#       log10(L/Lsun)=  -2.94739251E+00
#                Mass=   1.09384636E+30
#              Radius=   3.67084495E+10
#
#       log10(L/Lsun)=  -3.02702179E+00
#                Mass=   1.02041159E+30
#              Radius=   3.49859541E+10
#
#       log10(L/Lsun)=  -3.02811725E+00
#                Mass=   1.02131643E+30
#              Radius=   3.49089017E+10
#
#                          create initial model iteration          14
#       log10(L/Lsun)=  -3.09002683E+00
#                Mass=   9.85839593E+29
#              Radius=   3.32764667E+10
#
#       log10(L/Lsun)=  -3.00564711E+00
#                Mass=   1.05549840E+30
#              Radius=   3.49534099E+10
#
#       log10(L/Lsun)=  -3.09096069E+00
#                Mass=   9.86653985E+29
#              Radius=   3.32055907E+10
#
#                          create initial model iteration          15
#       log10(L/Lsun)=  -3.26320427E+00
#                Mass=   9.53414032E+29
#              Radius=   3.16670262E+10
#
#       log10(L/Lsun)=  -3.06439870E+00
#                Mass=   1.01925933E+30
#              Radius=   3.32933244E+10
#
#       log10(L/Lsun)=  -3.26557395E+00
#                Mass=   9.54160436E+29
#              Radius=   3.16021227E+10
#
#                          create initial model iteration          16
#       log10(L/Lsun)=  -3.14799281E+00
#                Mass=   9.85016893E+29
#              Radius=   3.16897136E+10
#
#       log10(L/Lsun)=  -3.28578033E+00
#                Mass=   9.22942970E+29
#              Radius=   3.00275334E+10
#
#       log10(L/Lsun)=  -3.28774778E+00
#                Mass=   9.23657079E+29
#              Radius=   2.99664087E+10
#
#                          create initial model iteration          17
#       log10(L/Lsun)=  -3.31564696E+00
#                Mass=   9.49032082E+29
#              Radius=   3.00728725E+10
#
#       log10(L/Lsun)=  -3.66892153E+00
#                Mass=   8.91068665E+29
#              Radius=   2.83905351E+10
#
#       log10(L/Lsun)=  -3.67085244E+00
#                Mass=   8.91780968E+29
#              Radius=   2.83329250E+10
#
#                          create initial model iteration          18
#       log10(L/Lsun)=  -3.41178799E+00
#                Mass=   8.56919892E+29
#              Radius=   2.67061332E+10
#
#       log10(L/Lsun)=  -3.34298096E+00
#                Mass=   9.10356890E+29
#              Radius=   2.82295840E+10
#
#       log10(L/Lsun)=  -3.41332132E+00
#                Mass=   8.57667941E+29
#              Radius=   2.66550479E+10
#
#                          create initial model iteration          19
#       log10(L/Lsun)=  -4.75846824E+00
#                Mass=   8.26306397E+29
#              Radius=   2.55707931E+10
#
#       log10(L/Lsun)=  -3.55754201E+00
#                Mass=   8.75318311E+29
#              Radius=   2.65650439E+10
#
#       log10(L/Lsun)=  -4.75918753E+00
#                Mass=   8.27117334E+29
#              Radius=   2.55174656E+10
#
#                          create initial model iteration          20
#       log10(L/Lsun)=  -4.72063464E+00
#                Mass=   8.51044245E+29
#              Radius=   2.55386007E+10
#
#       log10(L/Lsun)=  -4.84084505E+00
#                Mass=   8.05675739E+29
#              Radius=   2.43271353E+10
#
#       log10(L/Lsun)=  -4.84152747E+00
#                Mass=   8.06556875E+29
#              Radius=   2.42757997E+10
#
#                          create initial model iteration          21
#       log10(L/Lsun)=  -4.83289413E+00
#                Mass=   8.18613243E+29
#              Radius=   2.40045163E+10
#
#       log10(L/Lsun)=  -4.95337822E+00
#                Mass=   7.77577565E+29
#              Radius=   2.28905771E+10
#
#       log10(L/Lsun)=  -4.95399774E+00
#                Mass=   7.78573357E+29
#              Radius=   2.28417859E+10
#
#                          create initial model iteration          22
#       log10(L/Lsun)=  -4.96197693E+00
#                Mass=   7.85489943E+29
#              Radius=   2.24329586E+10
#
#       log10(L/Lsun)=  -5.08529250E+00
#                Mass=   7.48710465E+29
#              Radius=   2.14032771E+10
#
#       log10(L/Lsun)=  -5.08580635E+00
#                Mass=   7.49847258E+29
#              Radius=   2.13576270E+10
#
#                          create initial model iteration          23
#       log10(L/Lsun)=  -5.11925850E+00
#                Mass=   7.50773003E+29
#              Radius=   2.07807395E+10
#
#       log10(L/Lsun)=  -4.73606915E+00
#                Mass=   7.17999515E+29
#              Radius=   1.98362582E+10
#
#       log10(L/Lsun)=  -4.72917285E+00
#                Mass=   7.19299722E+29
#              Radius=   1.97943594E+10
#
#                          create initial model iteration          24
#       log10(L/Lsun)=  -4.33179794E+00
#                Mass=   6.84935082E+29
#              Radius=   1.82078327E+10
#
#       log10(L/Lsun)=  -4.53163871E+00
#                Mass=   7.14255650E+29
#              Radius=   1.90451024E+10
#
#       log10(L/Lsun)=  -4.32978392E+00
#                Mass=   6.86413710E+29
#              Radius=   1.81708197E+10
#
#                          create initial model iteration          25
#       log10(L/Lsun)=  -5.60893106E+00
#                Mass=   6.51719736E+29
#              Radius=   1.66756453E+10
#
#       log10(L/Lsun)=  -5.50890180E+00
#                Mass=   6.78430333E+29
#              Radius=   1.73985417E+10
#
#       log10(L/Lsun)=  -5.60944617E+00
#                Mass=   6.53376776E+29
#              Radius=   1.66439974E+10
#
#                          create initial model iteration          26
#       log10(L/Lsun)=  -5.77728115E+00
#                Mass=   6.21616095E+29
#              Radius=   1.52717022E+10
#
#       log10(L/Lsun)=  -5.68681730E+00
#                Mass=   6.46391530E+29
#              Radius=   1.58991754E+10
#
#       log10(L/Lsun)=  -5.77772373E+00
#                Mass=   6.23438379E+29
#              Radius=   1.52449320E+10
#
#                          create initial model iteration          27
#       log10(L/Lsun)=  -5.85220181E+00
#                Mass=   6.18165461E+29
#              Radius=   1.45831705E+10
#
#       log10(L/Lsun)=  -5.93909826E+00
#                Mass=   5.95037395E+29
#              Radius=   1.40400205E+10
#
#       log10(L/Lsun)=  -5.93945651E+00
#                Mass=   5.97011208E+29
#              Radius=   1.40176437E+10
#
#                          create initial model iteration          28
#  failed in kap_get get_kap_from_rhoT
#  temp too low in integration
# DATE: 2024-08-08
# TIME: 13:55:17
#
# ******************************************************************
# failed to create planet_create_0.2_Mj_0.5_Rj.mod when running inlist_create_header
# ******************************************************************
