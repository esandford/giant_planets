# %%
import numpy as np
import matplotlib.pyplot as plt

import matplotlib.style
import matplotlib as mpl
import matplotlib.colors as colors
import matplotlib.cm as cmx
mpl.style.use('classic')

import baraffe_tables
from baraffe_tables.table_search import baraffe_table_search

from astropy.table import Table
from astropy import units as u
from astropy.constants import G

import mesa_helper as mh
import os
import shutil

# %matplotlib inline

# %%
mJtomSun = u.jupiterMass.to(u.solMass)
mJtoGrams = u.jupiterMass.to(u.g)

rJtorSun = u.jupiterRad.to(u.solRad)
rJtoCm = u.jupiterRad.to(u.cm)

# %%
Minit = np.array((20.0, 14.0, 9.8, 6.9, 4.805, 3.4, 2.3, 1.6, 1.1, 0.82, 0.57, 0.4, 0.28))#, 0.2))
Minit_r12115 = np.array((20.0, 14.0, 9.8, 6.9, 4.8, 3.4, 2.3, 1.6, 1.1, 0.82, 0.57, 0.4, 0.28, 0.2))
#Rsuccess = np.array((5.0, 5.0, 5.0, 5.0, 2.0, 2.0, 2.0, 1.5))

# %%
fig, axes = plt.subplots(2,2, figsize=(20,20))
axes[0,0].set_xlabel(r"$\log{T_{eff}}\ [K]$")
axes[0,0].set_xlim(10**3.5, 10**1.5)
axes[0,0].set_ylabel(r"$\log{L/L_\odot}$")
axes[0,0].set_ylim(10**-9.5,10**-1.5)
axes[0,0].set_xscale("log")
axes[0,0].set_yscale("log")

axes[0,1].set_xlabel(r"$\log{\rho_c}\ [g/cm^3]$")
axes[0,1].set_ylabel(r"$\log{T_c}\ [K]$")

axes[1,0].set_xlabel(r"$\log{age}\ [yr]$")
axes[1,0].set_xlim(2.5e4,3.e10)
axes[1,0].set_ylabel(r"$\log{L/L_\odot}$")
axes[1,0].set_ylim(10**-10.5,10**-1.5)
axes[1,0].set_xscale("log")
axes[1,0].set_yscale("log")

axes[1,1].set_xlabel(r"$T_{eff}\ [K]$")
axes[1,1].set_xlim(3000,0)
axes[1,1].set_ylabel(r"$\log{g}\ [cm/s^2]$")
axes[1,1].set_ylim(5,1.5)

for ax in np.ravel(axes):
    ax.xaxis.get_label().set_fontsize(20)
    ax.yaxis.get_label().set_fontsize(20)

cm = plt.get_cmap('magma') 
cNorm  = colors.Normalize(vmin=np.log(np.min(Minit_r12115)), vmax=np.log(np.max(Minit_r12115))+0.15)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=cm)

for m in Minit:
    colorVal = scalarMap.to_rgba(np.log(m))
    
    history = Table.read("./Minit={0}Mj/LOGS/history.data".format(m), format="ascii", header_start=4, data_start=5)
    mask = (history['star_age'] > 5.e4)
    history = history[mask]
        
    axes[0,0].plot(history['Teff'], history['luminosity'], color=colorVal,marker='o')
    axes[0,1].plot(history['log_cntr_Rho'], history['log_cntr_T'], color=colorVal,marker='o')
    axes[1,0].plot(history['star_age'], history['luminosity'], color=colorVal,marker='o')
    axes[1,1].plot(history['Teff'], history['log_g'],color=colorVal, marker='o')

    axes[0,0].text(history['Teff'][0], history['luminosity'][0], s=r"${0} M_J$".format(m),color=colorVal,fontsize=15)
    axes[0,1].text(history['log_cntr_Rho'][0], history['log_cntr_T'][0], s=r"${0} M_J$".format(m),color=colorVal,fontsize=15)
    axes[1,0].text(history['star_age'][0], history['luminosity'][0], s=r"${0} M_J$".format(m),color=colorVal,fontsize=15)
    axes[1,1].text(history['Teff'][0], history['log_g'][0], s=r"${0} M_J$".format(m),color=colorVal,fontsize=15)
    
    ages = np.array(history['star_age'])
    baraffe_Ls = np.zeros_like(ages)
    baraffe_Teffs = np.zeros_like(ages)
    baraffe_loggs = np.zeros_like(ages)
    for i,age in enumerate(ages):
        row = baraffe_table_search(column="M/Ms", value=m*mJtomSun, age=age/1.e9, model="2003", age_interp=True)
        baraffe_Ls[i] = 10**row['L/Ls']
        baraffe_Teffs[i] = row['Teff']
        baraffe_loggs[i] = row['g']

    print(baraffe_Ls)
    print(baraffe_Teffs)
    axes[1,0].plot(ages, baraffe_Ls, color=colorVal, ls=":",lw=1,marker='x')
    axes[1,1].plot(baraffe_Teffs, baraffe_loggs, color=colorVal, ls=":",lw=1,marker='x')

for m in Minit_r12115:

    colorVal = scalarMap.to_rgba(np.log(m))
    
    history = Table.read("../reproducePaxton+2011fig18_r12115/Minit={0}Mj/LOGS/history.data".format(m), format="ascii", header_start=4, data_start=5)
    mask = (history['star_age'] > 5.e4)
    history = history[mask]
        
    axes[0,0].plot(10**history['log_Teff'], 10**history['log_L'], color=colorVal,ls="--",marker='v')
    axes[0,1].plot(history['log_cntr_Rho'], history['log_cntr_T'], color=colorVal,ls="--",marker='v')
    axes[1,0].plot(history['star_age'], 10**history['log_L'], color=colorVal,ls="--",marker='v')
    axes[1,1].plot(10**history['log_Teff'], history['log_g'],color=colorVal, ls="--",marker='v')

    axes[0,0].text(10**history['log_Teff'][0], 10**history['log_L'][0], s=r"${0} M_J$".format(m),color=colorVal,fontsize=15)
    axes[0,1].text(history['log_cntr_Rho'][0], history['log_cntr_T'][0], s=r"${0} M_J$".format(m),color=colorVal,fontsize=15)
    axes[1,0].text(history['star_age'][0], 10**history['log_L'][0], s=r"${0} M_J$".format(m),color=colorVal,fontsize=15)
    axes[1,1].text(10**history['log_Teff'][0], history['log_g'][0], s=r"${0} M_J$".format(m),color=colorVal,fontsize=15)
'''
    ages = np.array(history['star_age'])
    baraffe_Ls = np.zeros_like(ages)
    baraffe_Teffs = np.zeros_like(ages)
    baraffe_loggs = np.zeros_like(ages)
    for i,age in enumerate(ages):
        row = baraffe_table_search(column="M/Ms", value=m*mJtomSun, age=age/1.e9, model="2003", age_interp=True)
        baraffe_Ls[i] = 10**row['L/Ls']
        baraffe_Teffs[i] = row['Teff']
        baraffe_loggs[i] = row['g']

    print(baraffe_Ls)
    print(baraffe_Teffs)
    axes[1,0].plot(ages, baraffe_Ls, color=colorVal, ls=":",lw=1,marker='x')
    axes[1,1].plot(baraffe_Teffs, baraffe_loggs, color=colorVal, ls=":",lw=1,marker='x')
 '''
    
axes[1,0].plot(np.arange(3), np.arange(3), ls="-",marker='o', color=colorVal,label="irradiated MESA r24.03.01")
axes[1,0].plot(np.arange(3), np.arange(3), ls="--",marker='v', color=colorVal,label="MESA r12115")
axes[1,0].plot(np.arange(3), np.arange(3), ls=":",marker='x',color=colorVal, label="Baraffe 2003")
axes[1,0].legend(loc="best")
#plt.show()
plt.savefig("MESAr24.03.01_vs_MESAr12115_vs_baraffe2003.pdf",bbox_inches="tight")
#plt.savefig("MESAr24.03.01_vs_baraffe2003.pdf",bbox_inches="tight")
# Out:
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0031750920956305677 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.014521142085273067 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.051164563292419335 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.12651356353972726 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.22999731992819758 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.47757848683152115 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 1.1060767618534761 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 2.699066638122148 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 6.77935615951346 Gyr
# [4.87770986e-03 4.87770986e-03 2.93000082e-03 1.31957498e-03
#  2.28744346e-04 5.32383453e-05 2.98319626e-05 7.45289528e-06
#  2.53549199e-06 1.13421322e-06 2.65270078e-07 1.56431018e-07]
# [2468.74366261 2468.74366261 2441.07151509 2340.71481782 1899.1452434
#  1440.95279109 1293.7456126   941.55930951  733.47423149  621.41644015
#   430.63639717  378.28423922]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0030413355820292955 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.012199004244576445 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.04324037768968329 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.0824761725459356 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.16690252156691565 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.3830872909948947 Gyr
# Interpolating tables 0.500 Gyr and 1.000 Gyr to 0.9211353972084564 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 2.2811881725471426 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 7.208588880322944 Gyr
# [2.86921898e-03 2.86921898e-03 1.49638232e-03 4.45929336e-04
#  1.79479444e-04 7.21637241e-05 2.77913438e-05 7.55419897e-06
#  1.49319145e-06 6.70070505e-07 1.21731193e-07 7.61197479e-08
#  7.61197479e-08]
# [2356.92707426 2356.92707426 2264.42735288 2020.18806696 1752.47531718
#  1479.78801909 1221.32025125  930.7131577   627.99655379  529.48650683
#   348.04336778  309.8266044   309.8266044 ]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0029679434219528934 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.011890599479120165 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.028884015856037164 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.054631273708661617 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.12072788695114334 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.29225366627742855 Gyr
# Interpolating tables 0.500 Gyr and 1.000 Gyr to 0.7204222976907295 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 2.1437961038563977 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 5.663257508423652 Gyr
# [1.64430276e-03 1.64430276e-03 7.95301901e-04 1.51195111e-04
#  6.40815429e-05 2.01968293e-05 6.70668761e-06 3.05620671e-06
#  8.14192752e-07 3.02501291e-07 7.38486460e-08 3.68856442e-08
#  3.68856442e-08]
# [2222.62103369 2222.62103369 2070.48985477 1642.91868423 1407.75118941
#  1096.47517904  857.53693568  730.40456256  531.08965439  426.36676902
#   301.32211278  254.68037589  254.68037589]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0027710629533406854 Gyr
# Interpolating tables 0.005 Gyr and 0.010 Gyr to 0.00952991155803061 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.019325412637824644 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.04050321753087764 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.09736897006238829 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.24098425189242775 Gyr
# Interpolating tables 0.500 Gyr and 1.000 Gyr to 0.6271208791736216 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 1.969436812599108 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 4.325837582596195 Gyr
# [8.86865433e-04 8.86865433e-04 4.17335021e-04 7.58167446e-05
#  4.33210160e-05 1.45596970e-05 3.84726708e-06 1.73488634e-06
#  4.51707944e-07 1.61829326e-07 5.57448215e-08 1.61517222e-08
#  1.61517222e-08]
# [2059.14982015 2059.14982015 1863.0878673  1402.70627089 1266.55583818
#  1007.70595409  738.73441702  623.90992941  451.63667745  359.30912491
#   279.23129278  204.73400429  204.73400429]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.003651726299841485 Gyr
# Interpolating tables 0.005 Gyr and 0.010 Gyr to 0.0077272696103142195 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.017192948474021794 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.04196634693742548 Gyr
# Interpolating tables 0.100 Gyr and 0.120 Gyr to 0.1073630437889664 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.2814253288368273 Gyr
# Interpolating tables 0.500 Gyr and 1.000 Gyr to 0.921011054779078 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 2.0749985370003046 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 4.931163303823887 Gyr
# [4.37166109e-04 4.37166109e-04 1.30295049e-04 4.44557472e-05
#  2.09125486e-05 5.80467934e-06 1.58369103e-06 6.91515953e-07
#  1.38362295e-07 7.33622827e-08 1.89610350e-08 6.52626073e-09
#  6.52626073e-09 6.52626073e-09]
# [1837.37109531 1837.37109531 1514.95583463 1235.75671039 1064.75794529
#   806.64755808  591.66494935  496.70729829  336.81907958  294.73370561
#   210.86577975  162.49698177  162.49698177  162.49698177]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.00250613776483568 Gyr
# Interpolating tables 0.005 Gyr and 0.010 Gyr to 0.005295369932005891 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.012498499818817925 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.0326791775431088 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.08796830854220991 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.2632135473389239 Gyr
# Interpolating tables 0.500 Gyr and 1.000 Gyr to 0.7323351701319406 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 1.5981188843148963 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 4.218768581517401 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 8.080513674437894 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 9.882694634640625 Gyr
# [2.08374123e-04 2.08374123e-04 1.03774203e-04 3.11223145e-05
#  1.25046600e-05 4.51438053e-06 1.05793176e-06 3.95383889e-07
#  9.75544468e-08 4.71530956e-08 1.21133691e-08 4.19930442e-09
#  2.86199322e-09 2.79041373e-09 2.79041373e-09]
# [1600.65035673 1600.65035673 1426.64518201 1127.70755035  933.63133344
#   758.05044407  533.57279316  431.27032569  308.02901831  262.09180989
#   190.85116581  145.75887149  131.80317124  130.89488949  130.89488949]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0017034061565626927 Gyr
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.004073819676388232 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.010615374665997367 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.028824779954601674 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.08216524674479098 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.27604784941109173 Gyr
# Interpolating tables 0.500 Gyr and 1.000 Gyr to 0.6232030036235235 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 1.5468906569387928 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 3.3753555810158495 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 4.583843579651695 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 8.848552781178839 Gyr
# [8.69894519e-05 8.69894519e-05 6.31952342e-05 2.15844984e-05
#  5.81971960e-06 2.47316329e-06 5.93931720e-07 1.88306620e-07
#  5.72847456e-08 2.32351719e-08 8.16523258e-09 4.09495243e-09
#  3.00607630e-09 2.34963282e-09 2.34963282e-09 2.34963282e-09
#  2.34963282e-09 2.34963282e-09]
# [1337.41188582 1337.41188582 1267.44323509 1031.65476459  775.86486978
#   652.65752474  463.65422412  361.51885967  270.15428927  221.0488041
#   175.72529898  145.76943071  133.521       125.          125.
#   125.          125.          125.        ]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0022693569456049955 Gyr
# Interpolating tables 0.005 Gyr and 0.010 Gyr to 0.007528450481882517 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.022205717380293262 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.07327098250077567 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.2100688530542686 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.46316134713962787 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 1.1742271318647168 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 2.37555401915671 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 4.616593144005054 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 9.174687629872674 Gyr
# [3.88873857e-05 3.88873857e-05 2.17784794e-05 4.08841436e-06
#  1.58100602e-06 3.30304019e-07 1.20692332e-07 3.97362945e-08
#  2.48885732e-08 1.23879659e-08 3.36511569e-09 2.79898132e-09
#  2.34963282e-09 2.34963282e-09]
# [1122.8813156  1122.8813156  1013.92238562  713.33677254  583.80315255
#   405.45468982  325.27305307  250.30011671  221.775       192.643
#   138.298       131.107       125.          125.        ]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.00132357849207568 Gyr
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0038196326754466473 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.010620914987344804 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.0359785101961953 Gyr
# Interpolating tables 0.100 Gyr and 0.120 Gyr to 0.10862092282651342 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.2601618822304066 Gyr
# Interpolating tables 0.500 Gyr and 1.000 Gyr to 0.7303134437483002 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 1.997124885782446 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 8.995362980060088 Gyr
# [2.06030262e-05 2.06030262e-05 1.77431662e-05 5.56906037e-06
#  1.40469048e-06 4.89640960e-07 1.08263118e-07 5.27994768e-08
#  1.19352331e-08 1.54170045e-08 2.91071712e-09 2.34963282e-09]
# [959.16840448 959.16840448 934.71318118 746.07105166 547.68012846
#  440.22431704 308.59863924 265.75177313 186.5775282  201.82
#  132.434      125.        ]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0015247901219068085 Gyr
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.004540319132367495 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.014068619918500598 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.050912830618468435 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.12273504601836807 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.31770395061639545 Gyr
# Interpolating tables 0.500 Gyr and 1.000 Gyr to 0.9127188963311091 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 3.2034688719801427 Gyr
# [1.00097937e-05 1.00097937e-05 7.94462087e-06 2.10760469e-06
#  6.86635121e-07 1.57406302e-07 5.51719989e-08 2.17426979e-08
#  3.99098846e-09 7.65596607e-09 2.34963282e-09 2.34963282e-09]
# [805.57784672 805.57784672 773.60608021 589.89093248 462.25975862
#  334.8595092  264.81303099 218.94731566 145.23139052 172.566
#  125.         125.        ]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0013242588434656595 Gyr
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.00435046271689544 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.018778265229275056 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.05077903751199774 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.12492195117735178 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.36624400250317335 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 1.1085305006398225 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 5.443122092727087 Gyr
# [4.87298994e-06 4.26667551e-06 1.22056256e-06 3.26190766e-07
#  9.29912750e-08 3.19803630e-08 8.93005675e-09 2.58821292e-08
#  6.20869034e-09 2.34963282e-09]
# [655.70655199 640.78844215 501.56000518 381.87731456 292.21151477
#  231.8792625  176.9280779  223.368      158.721      125.        ]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.004621831158079295 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.017771053295360204 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.047772668418771126 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.1380005907438336 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.4061601027869793 Gyr
# Interpolating tables 0.500 Gyr and 1.000 Gyr to 0.9315884736163776 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 2.4745249661117557 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 9.733439941254332 Gyr
# [4.26579519e-06 4.26579519e-06 9.72747224e-07 3.06196343e-07
#  9.31107875e-08 2.70395836e-08 6.38263486e-09 1.61808004e-09
#  1.16949939e-08 2.48885732e-09 2.34963282e-09]
# [628.    628.    471.356 372.824 291.069 222.926 162.237 115.105 190.243
#  126.973 125.   ]
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.004621831158079295 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.017763949545469712 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.0531217266412013 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.21984821638254917 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 1.11950461806423 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 6.689939928002016 Gyr
# [4.26579519e-06 4.26579519e-06 9.72747224e-07 3.06196343e-07
#  8.10961058e-08 1.73780083e-08 2.57039578e-08 4.76430987e-09
#  2.34963282e-09]
# [628.    628.    471.356 372.843 282.19  204.403 223.102 149.494 125.   ]

# %%
# read in MESA results
history_2RJ = Table.read("./MESA_make_planets_0.01Msun/LOGS/history.data", format="ascii", header_start=4, data_start=5)
print(history.colnames)
# Out:
# ['model_number', 'num_zones', 'star_age', 'log_dt', 'star_mass', 'mass_conv_core', 'Teff', 'log_L', 'log_R', 'log_g', 'log_cntr_P', 'log_cntr_Rho', 'log_cntr_T', 'total_mass_h1', 'total_mass_he3', 'total_mass_he4', 'total_mass_c12', 'total_mass_n14', 'total_mass_o16', 'total_mass_ne20', 'total_mass_mg24', 'num_retries', 'num_iters', 'elapsed_time']

# %%
# read in MESA results
history_3RJ = Table.read("./MESA_make_planets_0.01Msun/LOGS/history.data", format="ascii", header_start=4, data_start=5)
print(history.colnames)
# Out:
# ['model_number', 'num_zones', 'star_age', 'log_dt', 'star_mass', 'mass_conv_core', 'Teff', 'log_L', 'log_R', 'log_g', 'log_cntr_P', 'log_cntr_Rho', 'log_cntr_T', 'total_mass_h1', 'total_mass_he3', 'total_mass_he4', 'total_mass_c12', 'total_mass_n14', 'total_mass_o16', 'total_mass_ne20', 'total_mass_mg24', 'num_retries', 'num_iters', 'elapsed_time']

# %%
# search baraffe tables for 0.01 Msun object
mp_arr = np.array((0.01)) #msun
mp_arr = np.atleast_1d(mp_arr)
age_arr = 10**np.linspace(6.,10.,25)/1.e9
L_matrix = np.zeros((len(mp_arr),len(age_arr)))
Teff_matrix = np.zeros((len(mp_arr),len(age_arr)))

for i, mp in enumerate(mp_arr):
    for j, age in enumerate(age_arr):
        row = baraffe_table_search(column="M/Ms", value=mp, age=age, model="2003", age_interp=True)
        #sprint(row)
        L_matrix[i,j] = row['L/Ls']
        Teff_matrix[i,j] = row['Teff']
# Out:
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0014677992676220707 Gyr
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0021544346900318825 Gyr
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0031622776601683794 Gyr
# Interpolating tables 0.001 Gyr and 0.005 Gyr to 0.0046415888336127815 Gyr
# Interpolating tables 0.005 Gyr and 0.010 Gyr to 0.006812920690579608 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.014677992676220676 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.021544346900318825 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.03162277660168379 Gyr
# Interpolating tables 0.010 Gyr and 0.050 Gyr to 0.046415888336127725 Gyr
# Interpolating tables 0.050 Gyr and 0.100 Gyr to 0.06812920690579607 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.14677992676220677 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.21544346900318778 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.31622776601683794 Gyr
# Interpolating tables 0.120 Gyr and 0.500 Gyr to 0.4641588833612773 Gyr
# Interpolating tables 0.500 Gyr and 1.000 Gyr to 0.6812920690579595 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 1.4677992676220675 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 2.154434690031878 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 3.1622776601683795 Gyr
# Interpolating tables 1.000 Gyr and 5.000 Gyr to 4.641588833612773 Gyr
# Interpolating tables 5.000 Gyr and 10.000 Gyr to 6.8129206905795945 Gyr

# %%
fig, axes = plt.subplots(1,3,figsize=(21,6))
axes[0].plot(history_2RJ['star_age'],history_2RJ['log_L'],'k-')

axes[0].plot(history_3RJ['star_age'],history_3RJ['log_L'],'r-')

for i, mp in enumerate(mp_arr):
    axes[0].plot(age_arr*1.e9, L_matrix[i], ':')
    
axes[0].set_xlabel("age [yr]")
axes[0].set_ylabel("log_10(L [Lsun])")
axes[0].set_xscale("log")
axes[0].set_xlim(1.e6,1.e10)



axes[1].plot(history_2RJ['star_age'],history_2RJ['log_R'],'k-')

axes[1].plot(history_3RJ['star_age'],history_3RJ['log_R'],'r-')

axes[1].set_xlabel("age [yr]")
axes[1].set_ylabel("log_10(R [Rsun])")
axes[1].set_xscale("log")
axes[1].set_xlim(1.e6,1.e10)

cs = axes[2].scatter(history_2RJ['Teff'],history_2RJ['log_g'],c=np.log10(history_2RJ['star_age']),marker='.',s=200,edgecolor='None',cmap='plasma_r')
axes[2].plot(history_3RJ['Teff'], history_3RJ['log_g'],'r.')
axes[2].set_xlabel("Teff [k]")
axes[2].set_ylabel("log(g [cm/s^2])")
axes[2].set_xlim(3000,0)
axes[2].set_ylim(5.75,2.9)

cax = plt.axes((0.91, 0.1, 0.01, 0.8))
plt.colorbar(cs,cax=cax,label="log_10(age [yr])")

plt.show()

# %%
fig, axes = plt.subplots(2,1,figsize=(8,12))
for i, mp in enumerate(mp_arr):
    axes[0].plot(age_arr*1.e9, L_matrix[i], '-',label="{0} M_J".format(mp/0.0009545942339693249))
    axes[1].plot(age_arr*1.e9, Teff_matrix[i], '-',label="{0} M_J".format(mp/0.0009545942339693249))
axes[0].legend(loc="best")
axes[1].legend(loc="best")
axes[0].set_xscale("log")
axes[1].set_xscale("log")

axes[0].set_xlabel("t [yr]")
axes[1].set_xlabel("t [yr]")
axes[0].set_ylabel("log_10[L/Lsun]")
axes[1].set_ylabel("Teff [K]")

axes[0].set_xlim(1.e6,1.e10)
axes[1].set_xlim(1.e6,1.e10)

plt.show()
