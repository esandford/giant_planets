# %%
import EOSutils as meos

import numpy as np
import matplotlib.pyplot as plt

import matplotlib.style
import matplotlib as mpl
import matplotlib.colors as colors
import matplotlib.cm as cmx
from mpl_toolkits.axes_grid1 import make_axes_locatable

mpl.style.use('classic')

from astropy.table import Table
from astropy import units as u
from astropy.constants import G

import mesa_helper as mh
import os
import shutil
import copy

from scipy import interpolate, optimize
from scipy.linalg import lstsq as scipy_lstsq
from scipy.ndimage import gaussian_filter
import scipy.integrate as integrate
import decimal 

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
def read_CMSlike(filename,X,Y):
    """
    read in a data table in CMS-like format, where columns are
    log10T[K] log10P[erg/cm3] log10rho[g/cm3] log10E[erg/g] log10S[erg/g/K]
    """
    data = np.genfromtxt(filename)
    EOStable = meos.simple_table()

    EOStable.X = X
    EOStable.Y = Y
    EOStable.Z = 1.0 - X - Y

    EOStable.atomic_number = EOStable.X + 2*(1.-EOStable.X)
    EOStable.mass_number = EOStable.X + 4*(1.-EOStable.X)

    EOStable.independent_arr_1 = np.unique(data[:,0])
    EOStable.independent_arr_2 = np.unique(data[:,2])

    nT = len(EOStable.independent_arr_1)
    nrho = len(EOStable.independent_arr_2)

    EOStable.independent_var_1 = 'T'
    EOStable.independent_var_2 = 'rho'

    EOStable.log10Tgrid, EOStable.log10rhogrid = np.meshgrid(EOStable.independent_arr_1, EOStable.independent_arr_2)
    EOStable.log10Pgrid = np.zeros_like(EOStable.log10Tgrid)
    EOStable.log10Egrid = np.zeros_like(EOStable.log10Tgrid)
    EOStable.log10Sgrid = np.zeros_like(EOStable.log10Tgrid)
    
    for i in range(nT):
        EOStable.log10Pgrid[:,i] = data[:,1][i*nrho : (i+1)*nrho]
        EOStable.log10Egrid[:,i] = data[:,3][i*nrho : (i+1)*nrho]
        EOStable.log10Sgrid[:,i] = data[:,4][i*nrho : (i+1)*nrho]
             
    return EOStable

# %% [markdown]
# # change SCVH coords from (P, T) to (rho, T)

# %%
#CMS19_H = meos.CMStable("../../2021_chabrier+_tables/TABLE_H_Trho_v1",units='cgs',F_smoothing_kernel=5)
#CMS19_He = meos.CMStable("../../2021_chabrier+_tables/TABLE_HE_Trho_v1",units='cgs',F_smoothing_kernel=5)

H_QT = meos.read_MESAtable("../../meos_MESAformat_CMS19+HG23+rock+water/mesa-planetblend_00z100x.data")

H_arr, CMS19_H = meos.reshapeQTgrid(H_QT,lower_logRho_bound=-8,upper_logRho_bound=6,rounding=2)
CMS19_H.X = 1.
CMS19_H.Y = 0.
CMS19_H.Z = 0.

CMS19_H.independent_arr_1 = np.arange(2.0,8.01,0.05)
CMS19_H.independent_arr_2 = np.arange(-8.0,6.01,0.05)
CMS19_H.compute_atomic_number()


He_QT = meos.read_MESAtable("../../meos_MESAformat_CMS19+HG23+rock+water/mesa-planetblend_00z00x.data")

He_arr, CMS19_He = meos.reshapeQTgrid(He_QT,lower_logRho_bound=-8,upper_logRho_bound=6,rounding=2)
CMS19_He.X = 1.
CMS19_He.Y = 0.
CMS19_He.Z = 0.

CMS19_He.independent_arr_1 = np.arange(2.0,8.01,0.05)
CMS19_He.independent_arr_2 = np.arange(-8.0,6.01,0.05)
CMS19_He.compute_atomic_number()


Z_QT = meos.read_MESAtable("../../meos_MESAformat_CMS19+HG23+rock+water/mesa-planetblend_100z00x.data")

Z_arr, Z = meos.reshapeQTgrid(Z_QT,lower_logRho_bound=-8,upper_logRho_bound=6,rounding=2)
Z.X = 0.
Z.Y = 0.
Z.Z = 1.

Z.independent_arr_1 = np.arange(2.0,8.01,0.05)
Z.independent_arr_2 = np.arange(-8.0,6.01,0.05)
Z.compute_atomic_number()

# %%
SCVH_H = meos.SCVHtable("../../1995_SCVH/h_tab_i.dat",units='cgs',F_smoothing_kernel=5)
SCVH_He = meos.SCVHtable("../../1995_SCVH/he_tab_i.dat",units='cgs',F_smoothing_kernel=5)

SCVH_H_ = meos.simple_table()
SCVH_H_.X = 1.
SCVH_H_.Y = 0.
SCVH_H_.atomic_number = SCVH_H_.X + 2*(1.-SCVH_H_.X)
SCVH_H_.mass_number = SCVH_H_.X + 4*(1.-SCVH_H_.X)


start_Tgrid = SCVH_H.log10Tgrid
start_Pgrid = SCVH_H.log10Pgrid
start_rhogrid = SCVH_H.log10rhogrid
start_Sgrid = SCVH_H.log10Sgrid
start_Ugrid = SCVH_H.log10Egrid

start_Tarr = SCVH_H.independent_arr_1
start_Parr = SCVH_H.independent_arr_2

# re-interpolate to (rho, T) for plot comparison
desired_Tarr = start_Tarr
desired_rhoarr = np.arange(-8.0,3.5,0.05)
SCVH_H_.log10Tgrid, SCVH_H_.log10rhogrid = np.meshgrid(desired_Tarr, desired_rhoarr)
SCVH_H_.log10Pgrid = None
SCVH_H_.log10Sgrid = None
SCVH_H_.log10Egrid = None

# construct an interpolator to get rho as a function of (P, T)
interp_log10rho_given_log10P_log10T_linear = interpolate.RegularGridInterpolator(points=(start_Parr, start_Tarr), values=start_rhogrid, bounds_error=False, fill_value=None, method='linear')

def interp_log10rho(log10P, log10T):
    return interp_log10rho_given_log10P_log10T_linear((log10P,log10T))
           
def log10rho_abs_diff(log10P, log10rho, log10T):
    return np.abs(log10rho - interp_log10rho(log10P,log10T))


# construct interpolators to get S and U as functions of (P,T)
interp_log10S_given_log10P_log10T_linear = interpolate.RegularGridInterpolator(points=(start_Parr, start_Tarr), values=start_Sgrid, bounds_error=False, fill_value=None, method='linear')
interp_log10U_given_log10P_log10T_linear = interpolate.RegularGridInterpolator(points=(start_Parr, start_Tarr), values=start_Ugrid, bounds_error=False, fill_value=None, method='linear')


def reinterp_log10S(log10P, log10T, method='cubic'):
    return interp_log10S_given_log10P_log10T_linear((log10P,log10T))
            
def reinterp_log10U(log10P, log10T, method='cubic'):
    return interp_log10U_given_log10P_log10T_linear((log10P,log10T))

def solve_log10PSU(log10rho, log10T, log10P0=5.):
    opt = optimize.minimize(log10rho_abs_diff, x0=log10P0, args=(log10rho,log10T),bounds=[(1.0,24.0)], tol=1.e-10) 
    opt_log10P = opt.x[0]
        
    recorresponding_log10S = reinterp_log10S(opt_log10P, log10T)
    recorresponding_log10U = reinterp_log10U(opt_log10P, log10T)
    return opt_log10P, recorresponding_log10S, recorresponding_log10U


# interpolate!
log10Pgrid_reinterpolated = np.zeros_like(SCVH_H_.log10Tgrid)
log10Sgrid_reinterpolated = np.zeros_like(SCVH_H_.log10Tgrid)
log10Ugrid_reinterpolated = np.zeros_like(SCVH_H_.log10Tgrid)
        
for i in range(np.shape(SCVH_H_.log10Tgrid)[1]):
    this_log10T = SCVH_H_.log10Tgrid[0][i]
    for j in range(np.shape(SCVH_H_.log10rhogrid)[0]):
        this_log10rho = SCVH_H_.log10rhogrid[:,0][j]

        reinterpolated_log10P, reinterpolated_log10S, reinterpolated_log10U  = solve_log10PSU(log10rho=this_log10rho, log10T=this_log10T, log10P0=CMS19_H.log10Pgrid[j,i])
            
        log10Pgrid_reinterpolated[j,i] = reinterpolated_log10P
        log10Sgrid_reinterpolated[j,i] = reinterpolated_log10S
        log10Ugrid_reinterpolated[j,i] = reinterpolated_log10U

SCVH_H_.log10Pgrid = log10Pgrid_reinterpolated
SCVH_H_.log10Sgrid = log10Sgrid_reinterpolated
SCVH_H_.log10Egrid = log10Ugrid_reinterpolated


# mask arrays
SCVH_H_mask = ~meos.boundary_mask_rhoT(SCVH_H_) & ~meos.boundary_mask_PT(SCVH_H_)
SCVH_H_rho_toplot = np.ma.array(SCVH_H_.log10rhogrid, mask=~SCVH_H_mask, fill_value = np.nan)
SCVH_H_P_toplot = np.ma.array(SCVH_H_.log10Pgrid, mask=~SCVH_H_mask, fill_value = np.nan)
SCVH_H_E_toplot = np.ma.array(SCVH_H_.log10Egrid, mask=~SCVH_H_mask, fill_value = np.nan)
SCVH_H_S_toplot = np.ma.array(SCVH_H_.log10Sgrid, mask=~SCVH_H_mask, fill_value = np.nan)

SCVH_He_ = meos.simple_table()
SCVH_He_.X = 1.
SCVH_He_.Y = 0.
SCVH_He_.atomic_number = SCVH_He_.X + 2*(1.-SCVH_He_.X)
SCVH_He_.mass_number = SCVH_He_.X + 4*(1.-SCVH_He_.X)


start_Tgrid = SCVH_He.log10Tgrid
start_Pgrid = SCVH_He.log10Pgrid
start_rhogrid = SCVH_He.log10rhogrid
start_Sgrid = SCVH_He.log10Sgrid
start_Ugrid = SCVH_He.log10Egrid

start_Tarr = SCVH_He.independent_arr_1
start_Parr = SCVH_He.independent_arr_2

# re-interpolate to (rho, T) for plot comparison
desired_Tarr = start_Tarr
desired_rhoarr = np.arange(-8.0,3.5,0.05)
SCVH_He_.log10Tgrid, SCVH_He_.log10rhogrid = np.meshgrid(desired_Tarr, desired_rhoarr)
SCVH_He_.log10Pgrid = None
SCVH_He_.log10Sgrid = None
SCVH_He_.log10Egrid = None

# construct an interpolator to get rho as a function of (P, T)
interp_log10rho_given_log10P_log10T_linear = interpolate.RegularGridInterpolator(points=(start_Parr, start_Tarr), values=start_rhogrid, bounds_error=False, fill_value=None, method='linear')

def interp_log10rho(log10P, log10T):
    return interp_log10rho_given_log10P_log10T_linear((log10P,log10T))
           
def log10rho_abs_diff(log10P, log10rho, log10T):
    return np.abs(log10rho - interp_log10rho(log10P,log10T))


# construct interpolators to get S and U as functions of (P,T)
interp_log10S_given_log10P_log10T_linear = interpolate.RegularGridInterpolator(points=(start_Parr, start_Tarr), values=start_Sgrid, bounds_error=False, fill_value=None, method='linear')
interp_log10U_given_log10P_log10T_linear = interpolate.RegularGridInterpolator(points=(start_Parr, start_Tarr), values=start_Ugrid, bounds_error=False, fill_value=None, method='linear')


def reinterp_log10S(log10P, log10T, method='cubic'):
    return interp_log10S_given_log10P_log10T_linear((log10P,log10T))
            
def reinterp_log10U(log10P, log10T, method='cubic'):
    return interp_log10U_given_log10P_log10T_linear((log10P,log10T))

def solve_log10PSU(log10rho, log10T, log10P0=5.):
    opt = optimize.minimize(log10rho_abs_diff, x0=log10P0, args=(log10rho,log10T),bounds=[(1.0,24.0)], tol=1.e-10) 
    opt_log10P = opt.x[0]
        
    recorresponding_log10S = reinterp_log10S(opt_log10P, log10T)
    recorresponding_log10U = reinterp_log10U(opt_log10P, log10T)
    return opt_log10P, recorresponding_log10S, recorresponding_log10U


# interpolate!
log10Pgrid_reinterpolated = np.zeros_like(SCVH_He_.log10Tgrid)
log10Sgrid_reinterpolated = np.zeros_like(SCVH_He_.log10Tgrid)
log10Ugrid_reinterpolated = np.zeros_like(SCVH_He_.log10Tgrid)
        
for i in range(np.shape(SCVH_He_.log10Tgrid)[1]):
    this_log10T = SCVH_He_.log10Tgrid[0][i]
    for j in range(np.shape(SCVH_He_.log10rhogrid)[0]):
        this_log10rho = SCVH_He_.log10rhogrid[:,0][j]

        reinterpolated_log10P, reinterpolated_log10S, reinterpolated_log10U  = solve_log10PSU(log10rho=this_log10rho, log10T=this_log10T, log10P0=CMS19_He.log10Pgrid[j,i])
            
        log10Pgrid_reinterpolated[j,i] = reinterpolated_log10P
        log10Sgrid_reinterpolated[j,i] = reinterpolated_log10S
        log10Ugrid_reinterpolated[j,i] = reinterpolated_log10U

SCVH_He_.log10Pgrid = log10Pgrid_reinterpolated
SCVH_He_.log10Sgrid = log10Sgrid_reinterpolated
SCVH_He_.log10Egrid = log10Ugrid_reinterpolated


# mask arrays
SCVH_He_mask = ~meos.boundary_mask_rhoT(SCVH_He_) & ~meos.boundary_mask_PT(SCVH_He_)
SCVH_He_rho_toplot = np.ma.array(SCVH_He_.log10rhogrid, mask=~SCVH_He_mask, fill_value = np.nan)
SCVH_He_P_toplot = np.ma.array(SCVH_He_.log10Pgrid, mask=~SCVH_He_mask, fill_value = np.nan)
SCVH_He_E_toplot = np.ma.array(SCVH_He_.log10Egrid, mask=~SCVH_He_mask, fill_value = np.nan)
SCVH_He_S_toplot = np.ma.array(SCVH_He_.log10Sgrid, mask=~SCVH_He_mask, fill_value = np.nan)



# avoid a couple of jumpy little spots in the plot
SCVH_H_P_toplot[:,61][153:160] = np.nan
SCVH_H_S_toplot[:,61][153:160] = np.nan
SCVH_H_S_toplot[:,61][-10:] = np.nan

SCVH_He_P_toplot[:,61][163:173] = np.nan
SCVH_He_S_toplot[:,61][163:173] = np.nan
SCVH_He_S_toplot[:,61][-3:] = np.nan

# %%
def readin_and_mask_rhoT(filename, X, Y):

    table = read_CMSlike(filename=filename, X=X, Y=Y)

    mask = ~meos.boundary_mask_rhoT(table) & ~meos.boundary_mask_PT(table)
    rho_ = np.ma.array(table.log10rhogrid, mask=~mask, fill_value = np.nan)
    P_ = np.ma.array(table.log10Pgrid, mask=~mask, fill_value = np.nan)
    S_ = np.ma.array(table.log10Sgrid, mask=~mask, fill_value = np.nan)
    E_ = np.ma.array(table.log10Egrid, mask=~mask, fill_value = np.nan)

    return rho_, P_, S_, E_

# %%
def mask_rhoT(table):

    mask = ~meos.boundary_mask_rhoT(table) & ~meos.boundary_mask_PT(table)
    rho_ = np.ma.array(table.log10rhogrid, mask=~mask, fill_value = np.nan)
    P_ = np.ma.array(table.log10Pgrid, mask=~mask, fill_value = np.nan)
    S_ = np.ma.array(table.log10Sgrid, mask=~mask, fill_value = np.nan)
    E_ = np.ma.array(table.log10Egrid, mask=~mask, fill_value = np.nan)

    return rho_, P_, S_, E_

# %%
CMS19_H_rho_toplot, CMS19_H_P_toplot, CMS19_H_S_toplot, CMS19_H_E_toplot = mask_rhoT(CMS19_H)
CMS19_He_rho_toplot, CMS19_He_P_toplot, CMS19_He_S_toplot, CMS19_He_E_toplot = mask_rhoT(CMS19_He)
Z_rho_toplot, Z_P_toplot, Z_S_toplot, Z_E_toplot = mask_rhoT(Z)

CMS19_He_E_toplot[:,60][-81:] = np.nan
CMS19_He_S_toplot[:,60][-81:] = np.nan

# %% [markdown]
# # Plot

# %%
#scvh_T_idxs = np.array((11,24,36,49,61))
#scvh_T_idxs = np.array((0,11,24,36,49,61))
scvh_T_idxs = np.array((5,11,24,36,49,61))
print(SCVH_H.independent_arr_1[scvh_T_idxs])
print(np.round(SCVH_H.independent_arr_1[scvh_T_idxs],1))

#cms_T_idxs = np.array((20,40,60,80,100))
#cms_T_idxs = np.array((2,20,40,60,80,100))
cms_T_idxs = np.array((10,20,40,60,80,100))

print(cms_T_idxs)
print(CMS19_H.independent_arr_1[cms_T_idxs])
# Out:
# [2.5  2.98 4.02 4.98 6.02 6.98]
# [2.5 3.  4.  5.  6.  7. ]
# [ 10  20  40  60  80 100]
# [2.5 3.  4.  5.  6.  7. ]

# %%
#smoothing = np.array((1,2,5,10))
smoothing = np.array((2))
smoothing = np.atleast_1d(smoothing)
#scalingfac = np.array((0.05,0.1,0.25))
scalingfac = np.array((0.25))
scalingfac = np.atleast_1d(scalingfac)

smoothingcolors = ['y','r','m','g']
sfacls = ['--','-.',':']

mpl.rcParams['lines.linewidth'] = 2

# rewrite for easier plotting of original, TC, and control EoS
fig, axes = plt.subplots(3,3,figsize=(24,18))

for i,si in enumerate(scvh_T_idxs):
    if i==0:
        # log10P
        axes[0,0].plot(SCVH_H_rho_toplot[:,si], SCVH_H_P_toplot[:,si], 'k--', label="SCVH")
        axes[0,1].plot(SCVH_He_rho_toplot[:,si], SCVH_He_P_toplot[:,si], 'k--', label="SCVH")

        # log10 E
        axes[1,0].plot(SCVH_H_rho_toplot[:,si], SCVH_H_E_toplot[:,si], 'k--', label="SCVH")
        axes[1,1].plot(SCVH_He_rho_toplot[:,si], SCVH_He_E_toplot[:,si], 'k--', label="SCVH")
        
        # log10S
        axes[2,0].plot(SCVH_H_rho_toplot[:,si], SCVH_H_S_toplot[:,si], 'k--', label="SCVH")
        axes[2,1].plot(SCVH_He_rho_toplot[:,si], SCVH_He_S_toplot[:,si], 'k--', label="SCVH")

        # isochrone labels
        axes[0,0].text(x=SCVH_H_rho_toplot[:,si][0], y=SCVH_H_P_toplot[:,si][0] - 0.25, s=r"$10^{2.5}\mathrm{K}$",rotation=32,fontsize=20)
        axes[0,1].text(x=SCVH_He_rho_toplot[:,si][0], y=SCVH_He_P_toplot[:,si][0] - 0.25, s=r"$10^{2.5}\mathrm{K}$",rotation=32,fontsize=20)
        axes[0,2].text(x=SCVH_He_rho_toplot[:,si][0], y=SCVH_He_P_toplot[:,si][0] - 1.25, s=r"$10^{2.5}\mathrm{K}$",rotation=32,fontsize=20)
    
        axes[1,0].text(x=SCVH_H_rho_toplot[:,si][0], y=0.95*SCVH_H_E_toplot[:,si][0], s=r"$10^{2.5}\mathrm{K}$",fontsize=20)
        axes[1,1].text(x=SCVH_He_rho_toplot[:,si][0], y=0.95*SCVH_He_E_toplot[:,si][0], s=r"$10^{2.5}\mathrm{K}$",fontsize=20)
        axes[1,2].text(x=SCVH_He_rho_toplot[:,si][0], y=0.97*SCVH_He_E_toplot[:,si][0], s=r"$10^{2.5}\mathrm{K}$",fontsize=20)

        axes[2,0].text(x=SCVH_H_rho_toplot[:,si][0], y=0.98*SCVH_H_S_toplot[:,si][0], s=r"$10^{2.5}\mathrm{K}$",rotation=-25,fontsize=20)
        axes[2,1].text(x=SCVH_He_rho_toplot[:,si][0], y=0.98*SCVH_He_S_toplot[:,si][0], s=r"$10^{2.5}\mathrm{K}$",rotation=-25,fontsize=20)
        axes[2,2].text(x=SCVH_He_rho_toplot[:,si][0], y=0.89*SCVH_He_S_toplot[:,si][0], s=r"$10^{2.5}\mathrm{K}$",rotation=-25,fontsize=20)
        
        
    else:
        axes[0,0].plot(SCVH_H_rho_toplot[:,si], SCVH_H_P_toplot[:,si], 'k--')
        axes[0,1].plot(SCVH_He_rho_toplot[:,si], SCVH_He_P_toplot[:,si], 'k--')

        # log10 E
        axes[1,0].plot(SCVH_H_rho_toplot[:,si], SCVH_H_E_toplot[:,si], 'k--')
        axes[1,1].plot(SCVH_He_rho_toplot[:,si], SCVH_He_E_toplot[:,si], 'k--')
        
        # log10S
        axes[2,0].plot(SCVH_H_rho_toplot[:,si], SCVH_H_S_toplot[:,si], 'k--')
        axes[2,1].plot(SCVH_He_rho_toplot[:,si], SCVH_He_S_toplot[:,si], 'k--')

        # isochrone labels
        T = int(np.round(SCVH_H.independent_arr_1[si],1))

        axes[0,0].text(x=SCVH_H_rho_toplot[:,si][30*i], y=SCVH_H_P_toplot[:,si][30*i] - 0.2, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",rotation=32,fontsize=20)
        axes[0,1].text(x=SCVH_He_rho_toplot[:,si][30*i], y=SCVH_He_P_toplot[:,si][30*i] - 0.2, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",rotation=32,fontsize=20)
        axes[0,2].text(x=SCVH_He_rho_toplot[:,si][30*i], y=SCVH_He_P_toplot[:,si][30*i] - 0.5, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",rotation=32,fontsize=20)
    
        axes[1,0].text(x=SCVH_H_rho_toplot[:,si][0], y=SCVH_H_E_toplot[:,si][0] - 0.01, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",fontsize=20)
        axes[1,1].text(x=SCVH_He_rho_toplot[:,si][0], y=SCVH_He_E_toplot[:,si][0] - 0.01, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",fontsize=20)
        axes[1,2].text(x=SCVH_He_rho_toplot[:,si][0], y=SCVH_He_E_toplot[:,si][0] - 0.01, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",fontsize=20)

        axes[2,0].text(x=SCVH_H_rho_toplot[:,si][20*i], y=SCVH_H_S_toplot[:,si][20*i] - 0.09, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",rotation=-25,fontsize=20)
        axes[2,1].text(x=SCVH_He_rho_toplot[:,si][20*i], y=SCVH_He_S_toplot[:,si][20*i] - 0.09, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",rotation=-25,fontsize=20)
        if i==1:
            axes[2,2].text(x=SCVH_He_rho_toplot[:,si][20*i], y=0.93*SCVH_He_S_toplot[:,si][20*i] - 0.2, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",rotation=-25,fontsize=20)
        elif i==2:
            axes[2,2].text(x=SCVH_He_rho_toplot[:,si][20*i], y=0.98*SCVH_He_S_toplot[:,si][20*i] - 0.2, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",rotation=-25,fontsize=20)
        elif i==3:
            axes[2,2].text(x=SCVH_He_rho_toplot[:,si][20*i], y=0.98*SCVH_He_S_toplot[:,si][20*i] - 0.2, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",rotation=-25,fontsize=20)
        elif i==4:
            axes[2,2].text(x=SCVH_He_rho_toplot[:,si][20*i], y=0.99*SCVH_He_S_toplot[:,si][20*i] - 0.2, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",rotation=-25,fontsize=20)
        elif i==5:
            axes[2,2].text(x=SCVH_He_rho_toplot[:,si][20*i], y=0.995*SCVH_He_S_toplot[:,si][20*i] - 0.2, s=r"$10^{0}$".format(T)+r"$\mathrm{K}$",rotation=-25,fontsize=20)
        
for i,ci in enumerate(cms_T_idxs):
    if i==0:
        # log10P
        axes[0,0].plot(CMS19_H_rho_toplot[:,ci], CMS19_H_P_toplot[:,ci], 'b-', label="orig M22/CMS19")
        axes[0,1].plot(CMS19_He_rho_toplot[:,ci], CMS19_He_P_toplot[:,ci], 'b-', label="orig CMS19")
        axes[0,2].plot(Z_rho_toplot[:,ci], Z_P_toplot[:,ci], 'b-', label="orig Z")
       
        # log10 E
        axes[1,0].plot(CMS19_H_rho_toplot[:,ci], CMS19_H_E_toplot[:,ci], 'b-', label="orig M22/CMS19")
        axes[1,1].plot(CMS19_He_rho_toplot[:,ci], CMS19_He_E_toplot[:,ci], 'b-', label="orig CMS19")
        axes[1,2].plot(Z_rho_toplot[:,ci], Z_E_toplot[:,ci], 'b-', label="orig Z")
       
        
        # log10S
        axes[2,0].plot(CMS19_H_rho_toplot[:,ci], CMS19_H_S_toplot[:,ci], 'b-', label="orig M22/CMS19")
        axes[2,1].plot(CMS19_He_rho_toplot[:,ci], CMS19_He_S_toplot[:,ci], 'b-', label="orig CMS19")
        axes[2,2].plot(Z_rho_toplot[:,ci], Z_S_toplot[:,ci], 'b-', label="orig Z")
       

    else:
        # log10P
        axes[0,0].plot(CMS19_H_rho_toplot[:,ci], CMS19_H_P_toplot[:,ci], 'b-')
        axes[0,1].plot(CMS19_He_rho_toplot[:,ci], CMS19_He_P_toplot[:,ci], 'b-')   
        axes[0,2].plot(Z_rho_toplot[:,ci], Z_P_toplot[:,ci], 'b-')
       

        # log10E
        axes[1,0].plot(CMS19_H_rho_toplot[:,ci], CMS19_H_E_toplot[:,ci], 'b-')
        axes[1,1].plot(CMS19_He_rho_toplot[:,ci], CMS19_He_E_toplot[:,ci], 'b-')
        axes[1,2].plot(Z_rho_toplot[:,ci], Z_E_toplot[:,ci], 'b-')
       

        # log10S
        axes[2,0].plot(CMS19_H_rho_toplot[:,ci], CMS19_H_S_toplot[:,ci], 'b-')
        axes[2,1].plot(CMS19_He_rho_toplot[:,ci], CMS19_He_S_toplot[:,ci], 'b-') 
        axes[2,2].plot(Z_rho_toplot[:,ci], Z_S_toplot[:,ci], 'b-')
       

    if ci==cms_T_idxs[3]:
        axes[2,1].plot(CMS19_He_rho_toplot[:,ci][-81:], CMS19_He_S_toplot[:,ci][-81:], 'ro') 

#for j, s in enumerate(smoothing[0:1]):
for j, s in enumerate(smoothing):

    H_QT = meos.read_MESAtable("../../meos_MESAformat_CMS19+HG23+rock+water/mesa-planetblend-TC_s={0}_00z100x.data".format(s))

    H_arr, H_table = meos.reshapeQTgrid(H_QT,lower_logRho_bound=-8,upper_logRho_bound=6,rounding=2)
    H_table.X = 1.
    H_table.Y = 0.
    H_table.Z = 0.
    
    H_table.independent_arr_1 = np.arange(2.0,8.01,0.05)
    H_table.independent_arr_2 = np.arange(-8.0,6.01,0.05)
    H_table.compute_atomic_number()
    
    
    He_QT = meos.read_MESAtable("../../meos_MESAformat_CMS19+HG23+rock+water/mesa-planetblend-TC_s={0}_00z00x.data".format(s))
    
    He_arr, He_table = meos.reshapeQTgrid(He_QT,lower_logRho_bound=-8,upper_logRho_bound=6,rounding=2)
    He_table.X = 1.
    He_table.Y = 0.
    He_table.Z = 0.
    
    He_table.independent_arr_1 = np.arange(2.0,8.01,0.05)
    He_table.independent_arr_2 = np.arange(-8.0,6.01,0.05)
    He_table.compute_atomic_number()


    Z_QT = meos.read_MESAtable("../../meos_MESAformat_CMS19+HG23+rock+water/mesa-planetblend-TC_s={0}_100z00x.data".format(s))
    
    Z_arr, Z_table = meos.reshapeQTgrid(Z_QT,lower_logRho_bound=-8,upper_logRho_bound=6,rounding=2)
    Z_table.X = 0.
    Z_table.Y = 0.
    Z_table.Z = 1.

    Z_table.independent_arr_1 = np.arange(2.0,8.01,0.05)
    Z_table.independent_arr_2 = np.arange(-8.0,6.01,0.05)
    Z_table.compute_atomic_number()

    tc_H_rho, tc_H_P, tc_H_S, tc_H_E = mask_rhoT(H_table)
    tc_He_rho, tc_He_P, tc_He_S, tc_He_E = mask_rhoT(He_table)
    tc_Z_rho, tc_Z_P, tc_Z_S, tc_Z_E = mask_rhoT(Z_table)

    for i,ci in enumerate(cms_T_idxs):
        if (s==1 or s==2 or s==5) and ci == 20:
            tc_He_E[:,ci][-115:] = np.nan
            
        if  (s==1 or s==2) and ci == 60:
            tc_He_E[:,ci][-81:] = np.nan
            tc_He_S[:,ci][-81:] = np.nan
        
        if i==0:
            # log10P
            axes[0,0].plot(tc_H_rho[:,ci], tc_H_P[:,ci], color=smoothingcolors[j],ls='-', label="F-derived".format(s))
            axes[0,1].plot(tc_He_rho[:,ci], tc_He_P[:,ci], color=smoothingcolors[j],ls='-', label="F-derived".format(s))
            axes[0,2].plot(tc_Z_rho[:,ci], tc_Z_P[:,ci], color=smoothingcolors[j],ls='-', label="F-derived".format(s))
           
            # log10 E
            axes[1,0].plot(tc_H_rho[:,ci], tc_H_E[:,ci], color=smoothingcolors[j],ls='-', label="F-derived".format(s))
            axes[1,1].plot(tc_He_rho[:,ci], tc_He_E[:,ci], color=smoothingcolors[j],ls='-', label="F-derived".format(s))
            axes[1,2].plot(tc_Z_rho[:,ci], tc_Z_E[:,ci], color=smoothingcolors[j],ls='-', label="F-derived".format(s))
           
            # log10S
            axes[2,0].plot(tc_H_rho[:,ci], tc_H_S[:,ci], color=smoothingcolors[j],ls='-', label="F-derived".format(s))
            axes[2,1].plot(tc_He_rho[:,ci], tc_He_S[:,ci], color=smoothingcolors[j],ls='-', label="F-derived".format(s))
            axes[2,2].plot(tc_Z_rho[:,ci], tc_Z_S[:,ci], color=smoothingcolors[j],ls='-', label="F-derived".format(s))
           
    
        else:
            # log10P
            axes[0,0].plot(tc_H_rho[:,ci], tc_H_P[:,ci], color=smoothingcolors[j],ls='-',)
            axes[0,1].plot(tc_He_rho[:,ci], tc_He_P[:,ci],color=smoothingcolors[j],ls='-',)  
            axes[0,2].plot(tc_Z_rho[:,ci], tc_Z_P[:,ci], color=smoothingcolors[j],ls='-')
           
    
            # log10E
            axes[1,0].plot(tc_H_rho[:,ci], tc_H_E[:,ci], color=smoothingcolors[j],ls='-',)
            axes[1,1].plot(tc_He_rho[:,ci], tc_He_E[:,ci], color=smoothingcolors[j],ls='-',)
            axes[1,2].plot(tc_Z_rho[:,ci], tc_Z_E[:,ci], color=smoothingcolors[j],ls='-',)
           
    
            # log10S
            axes[2,0].plot(tc_H_rho[:,ci], tc_H_S[:,ci], color=smoothingcolors[j],ls='-')
            axes[2,1].plot(tc_He_rho[:,ci], tc_He_S[:,ci], color=smoothingcolors[j],ls='-') 
            axes[2,2].plot(tc_Z_rho[:,ci], tc_Z_S[:,ci], color=smoothingcolors[j],ls='-')
           
        
    #for k, f in enumerate(scalingfac[2:]):
    for k, f in enumerate(scalingfac):

        H_QT = meos.read_MESAtable("../../meos_MESAformat_CMS19+HG23+rock+water/mesa-planetblend-control_s={0}_sf={1}_00z100x.data".format(s,f))

        H_arr, H_table = meos.reshapeQTgrid(H_QT,lower_logRho_bound=-8,upper_logRho_bound=6,rounding=2)
        H_table.X = 1.
        H_table.Y = 0.
        H_table.Z = 0.
        
        H_table.independent_arr_1 = np.arange(2.0,8.01,0.05)
        H_table.independent_arr_2 = np.arange(-8.0,6.01,0.05)
        H_table.compute_atomic_number()
        
        
        He_QT = meos.read_MESAtable("../../meos_MESAformat_CMS19+HG23+rock+water/mesa-planetblend-control_s={0}_sf={1}_00z00x.data".format(s,f))
        
        He_arr, He_table = meos.reshapeQTgrid(He_QT,lower_logRho_bound=-8,upper_logRho_bound=6,rounding=2)
        He_table.X = 1.
        He_table.Y = 0.
        He_table.Z = 0.
        
        He_table.independent_arr_1 = np.arange(2.0,8.01,0.05)
        He_table.independent_arr_2 = np.arange(-8.0,6.01,0.05)
        He_table.compute_atomic_number()

        Z_QT = meos.read_MESAtable("../../meos_MESAformat_CMS19+HG23+rock+water/mesa-planetblend-control_s={0}_sf={1}_100z00x.data".format(s,f))
        Z_arr, Z_table = meos.reshapeQTgrid(Z_QT,lower_logRho_bound=-8,upper_logRho_bound=6,rounding=2)
        Z_table.X = 0.
        Z_table.Y = 0.
        Z_table.Z = 1.
        
        Z_table.independent_arr_1 = np.arange(2.0,8.01,0.05)
        Z_table.independent_arr_2 = np.arange(-8.0,6.01,0.05)
        Z_table.compute_atomic_number()
        
        c_H_rho, c_H_P, c_H_S, c_H_E = mask_rhoT(H_table)
        c_He_rho, c_He_P, c_He_S, c_He_E = mask_rhoT(He_table)
        c_Z_rho, c_Z_P, c_Z_S, c_Z_E = mask_rhoT(Z_table)

    
        for i,ci in enumerate(cms_T_idxs):
            if (s==1 or s==2 or s==5) and ci == 20:
                c_He_E[:,ci][-115:] = np.nan
                
            if  (s==1 or s==2 or s==5 or s==10) and ci == 60:
                c_He_E[:,ci][-81:] = np.nan
                c_He_S[:,ci][-81:] = np.nan

            if (s == 5 and f==0.25 and ci==40) or (s==10 and f==0.1 and ci==40):
                c_He_E[:,ci][0:70] = np.nan

            if (s==10 and f==0.25 and ci==40):
                c_He_E[:,ci][0:120] = np.nan
    
            if i==0:
                label="control".format(s,f)
                #label=None
                # log10P
                axes[0,0].plot(c_H_rho[:,ci], c_H_P[:,ci], color=smoothingcolors[j],ls=sfacls[k], label=label)
                axes[0,1].plot(c_He_rho[:,ci], c_He_P[:,ci], color=smoothingcolors[j],ls=sfacls[k], label=label)
                axes[0,2].plot(c_Z_rho[:,ci], c_Z_P[:,ci], color=smoothingcolors[j],ls=sfacls[k], label=label)

                
                # log10 E
                axes[1,0].plot(c_H_rho[:,ci], c_H_E[:,ci], color=smoothingcolors[j],ls=sfacls[k], label=label)
                axes[1,1].plot(c_He_rho[:,ci], c_He_E[:,ci], color=smoothingcolors[j],ls=sfacls[k], label=label)
                axes[1,2].plot(c_Z_rho[:,ci], c_Z_E[:,ci], color=smoothingcolors[j],ls=sfacls[k], label=label)

                
                # log10S
                axes[2,0].plot(c_H_rho[:,ci], c_H_S[:,ci], color=smoothingcolors[j],ls=sfacls[k], label=label)
                axes[2,1].plot(c_He_rho[:,ci], c_He_S[:,ci], color=smoothingcolors[j],ls=sfacls[k], label=label)
                axes[2,2].plot(c_Z_rho[:,ci], c_Z_S[:,ci], color=smoothingcolors[j],ls=sfacls[k], label=label)

        
            else:
                # log10P
                axes[0,0].plot(c_H_rho[:,ci], c_H_P[:,ci], color=smoothingcolors[j],ls=sfacls[k])
                axes[0,1].plot(c_He_rho[:,ci], c_He_P[:,ci],color=smoothingcolors[j],ls=sfacls[k])   
                axes[0,2].plot(c_Z_rho[:,ci], c_Z_P[:,ci], color=smoothingcolors[j],ls=sfacls[k])

        
                # log10E
                axes[1,0].plot(c_H_rho[:,ci], c_H_E[:,ci], color=smoothingcolors[j],ls=sfacls[k])
                axes[1,1].plot(c_He_rho[:,ci], c_He_E[:,ci], color=smoothingcolors[j],ls=sfacls[k])
                axes[1,2].plot(c_Z_rho[:,ci], c_Z_E[:,ci], color=smoothingcolors[j],ls=sfacls[k])

        
                # log10S
                axes[2,0].plot(tc_H_rho[:,ci], tc_H_S[:,ci], color=smoothingcolors[j],ls=sfacls[k])
                axes[2,1].plot(tc_He_rho[:,ci], tc_He_S[:,ci], color=smoothingcolors[j],ls=sfacls[k])
                axes[2,2].plot(c_Z_rho[:,ci], c_Z_S[:,ci], color=smoothingcolors[j],ls=sfacls[k])


for ax in axes[0]:
    ax.set_ylabel(r"$\log_{10}{P}\ [\mathrm{erg}/\mathrm{cm}^3]$",fontsize=25)
    ax.set_ylim(0.,18)
    ax.legend(loc='best',frameon=False,fontsize=20)

for ax in axes[1]:
    ax.set_ylabel(r"$\log_{10}{E}\ [\mathrm{erg}/\mathrm{g}]$",fontsize=25)
    ax.set_ylim(9,16)

for ax in axes[2]:
    ax.set_ylabel(r"$\log_{10}{S}\ [\mathrm{erg}/\mathrm{g}/\mathrm{K}]$",fontsize=25)
    #ax.set_ylim(8,10)

axes[2,0].set_ylim(8.6,9.8)
axes[2,1].set_ylim(8.2,9.4)
axes[2,2].set_ylim(7.5,9.3)

for ax in np.ravel(axes):
    ax.set_xlim(-8,6)
    ax.set_xlabel(r"$\log_{10}{\rho}\ [\mathrm{g}/\mathrm{cm}^3]$",fontsize=25)
    ax.tick_params(axis='both', which='major', labelsize=20)
    

axes[0,0].set_title("Hydrogen",fontsize=30)
axes[0,1].set_title("Helium",fontsize=30)
axes[0,2].set_title("Z blend",fontsize=30)

plt.show()
#plt.savefig("./isotherm_eos_comparisons_simplified.pdf",bbox_inches='tight')
#plt.savefig("./isotherm_eos_comparisons.pdf",bbox_inches='tight')
#plt.savefig('./isotherm_eos_comparisons_XYZ_simplified.pdf',bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #smoothing = np.array((1,2,5,10))
# ----> 2 smoothing = np.array((2))
#       3 smoothing = np.atleast_1d(smoothing)
#       4 #scalingfac = np.array((0.05,0.1,0.25))
#
# NameError: name 'np' is not defined
